# %%
import pandas as pd
import requests as r
import json
import time
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import scipy.stats as st
# Out:
# C:\Users\eldiy\Anaconda3\lib\site-packages\statsmodels\tools\_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
df_final=pd.DataFrame()
for i in range(430):
    url=f'https://www.vivino.com/api/explore/explore?country_code=FR&country_codes[]=fr&currency_code=EUR&grape_filter=varietal&min_rating=1&order_by=discount_percent&order=desc&page={i+1}&price_range_max=500&price_range_min=0'
    headers="""accept: application/json
accept-encoding: gzip, deflate, br
accept-language: fr-FR,fr;q=0.9,en-US;q=0.8,en;q=0.7
cache-control: no-cache
content-type: application/json
cookie: __auc=d250f01d171789f6bc01e099098; _ga=GA1.2.856886893.1586866646; _hjid=5928cd6c-01ab-408f-a7d0-4e498792d411; recently_viewed=--39e17ac97cea794bf53cb06b51c56bae6e20c4c4; client_cache_key=UnlJYWMwUDM2ckhvTkpoRnhzOC9nZmFUU1ZYSGxSMFlDd3lRRysxbVFaND0tLVZRNm16dklYdzdRRnplZWIrYkEzSnc9PQ%3D%3D--57f4280d64518da7b568b85cc2f5b89ca3fd71e4; _gid=GA1.2.551177208.1587108779; _hp2_ses_props.3503103446=%7B%22r%22%3A%22https%3A%2F%2Fwww.vivino.com%2Fsearch%2Fwines%3Fq%3DMaison%2Bde%2Bla%2BChapelle%22%2C%22ts%22%3A1587110947926%2C%22d%22%3A%22www.vivino.com%22%2C%22h%22%3A%22%2Fsearch%2Fwines%22%2C%22q%22%3A%22%3Fq%3DMaison%2Bde%2Bla%2BChapelle%2B2018%22%7D; _hp2_id.3503103446=%7B%22userId%22%3A%228842742331230353%22%2C%22pageviewId%22%3A%226715115452731618%22%2C%22sessionId%22%3A%221536664878130474%22%2C%22identity%22%3Anull%2C%22trackerVersion%22%3A%224.0%22%7D; _ruby-web_session=...%3D%3D--747632e65a2dc494198dedfa9e7873ae78f5321d
pragma: no-cache
referer: https://www.vivino.com/explore?e=eJwNy00KgCAQBtDbzNoWLb9lHUBoFRE2agj5w2hRt8_140XBQDEkKIrmxagU8YdZE2NaNJWup8djJLhmLsoHbKic79T24oRdapRhXeXe6rrByw9MVhwY
sec-fetch-dest: empty
sec-fetch-mode: cors
sec-fetch-site: same-origin
user-agent: Mozilla/5.0 (Windows NT 6.3; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/80.0.3987.163 Safari/537.36
x-requested-with: XMLHttpRequest"""
    headers=dict([i.strip().split(': ') for i in headers.split('\n')])
    resp=r.get(url, headers=headers)
    if resp:
        print('ok')
    else:
        print('not ok')
    result=resp.json()
    df=pd.json_normalize(result)
    df1=pd.json_normalize(df['explore_vintage.matches'][0])
    df_final=df_final.append(df1)
    time.sleep(2)
    print(i)
# Out:
# ok
# 0
# ok
# 1
# ok
# 2
# ok
# 3
# ok
# 4
# ok
# 5
# ok
# 6
# ok
# 7
# ok
# 8
# ok
# 9
# ok
# 10
# ok
# 11
# ok
# 12
# ok
# 13
# ok
# 14
# ok
# 15
# ok
# 16
# ok
# 17
# ok
# 18
# ok
# 19
# ok
# 20
# ok
# 21
# ok
# 22
# ok
# 23
# ok
# 24
# ok
# 25
# ok
# 26
# ok
# 27
# ok
# 28
# ok
# 29
# ok
# 30
# ok
# 31
# ok
# 32
# ok
# 33
# ok
# 34
# ok
# 35
# ok
# 36
# ok
# 37
# ok
# 38
# ok
# 39
# ok
# 40
# ok
# 41
# ok
# 42
# ok
# 43
# ok
# 44
# ok
# 45
# ok
# 46
# ok
# 47
# ok
# 48
# ok
# 49
# ok
# 50
# ok
# 51
# ok
# 52
# ok
# 53
# ok
# 54
# ok
# 55
# ok
# 56
# ok
# 57
# ok
# 58
# ok
# 59
# ok
# 60
# ok
# 61
# ok
# 62
# ok
# 63
# ok
# 64
# ok
# 65
# ok
# 66
# ok
# 67
# ok
# 68
# ok
# 69
# ok
# 70
# ok
# 71
# ok
# 72
# ok
# 73
# ok
# 74
# ok
# 75
# ok
# 76
# ok
# 77
# ok
# 78
# ok
# 79
# ok
# 80
# ok
# 81
# ok
# 82
# ok
# 83
# ok
# 84
# ok
# 85
# ok
# 86
# ok
# 87
# ok
# 88
# ok
# 89
# ok
# 90
# ok
# 91
# ok
# 92
# ok
# 93
# ok
# 94
# ok
# 95
# ok
# 96
# ok
# 97
# ok
# 98
# ok
# 99
# ok
# 100
# ok
# 101
# ok
# 102
# ok
# 103
# ok
# 104
# ok
# 105
# ok
# 106
# ok
# 107
# ok
# 108
# ok
# 109
# ok
# 110
# ok
# 111
# ok
# 112
# ok
# 113
# ok
# 114
# ok
# 115
# ok
# 116
# ok
# 117
# ok
# 118
# ok
# 119
# ok
# 120
# ok
# 121
# ok
# 122
# ok
# 123
# ok
# 124
# ok
# 125
# ok
# 126
# ok
# 127
# ok
# 128
# ok
# 129
# ok
# 130
# ok
# 131
# ok
# 132
# ok
# 133
# ok
# 134
# ok
# 135
# ok
# 136
# ok
# 137
# ok
# 138
# ok
# 139
# ok
# 140
# ok
# 141
# ok
# 142
# ok
# 143
# ok
# 144
# ok
# 145
# ok
# 146
# ok
# 147
# ok
# 148
# ok
# 149
# ok
# 150
# ok
# 151
# ok
# 152
# ok
# 153
# ok
# 154
# ok
# 155
# ok
# 156
# ok
# 157
# ok
# 158
# ok
# 159
# ok
# 160
# ok
# 161
# ok
# 162
# ok
# 163
# ok
# 164
# ok
# 165
# ok
# 166
# ok
# 167
# ok
# 168
# ok
# 169
# ok
# 170
# ok
# 171
# ok
# 172
# ok
# 173
# ok
# 174
# ok
# 175
# ok
# 176
# ok
# 177
# ok
# 178
# ok
# 179
# ok
# 180
# ok
# 181
# ok
# 182
# ok
# 183
# ok
# 184
# ok
# 185
# ok
# 186
# ok
# 187
# ok
# 188
# ok
# 189
# ok
# 190
# ok
# 191
# ok
# 192
# ok
# 193
# ok
# 194
# ok
# 195
# ok
# 196
# ok
# 197
# ok
# 198
# ok
# 199
# ok
# 200
# ok
# 201
# ok
# 202
# ok
# 203
# ok
# 204
# ok
# 205
# ok
# 206
# ok
# 207
# ok
# 208
# ok
# 209
# ok
# 210
# ok
# 211
# ok
# 212
# ok
# 213
# ok
# 214
# ok
# 215
# ok
# 216
# ok
# 217
# ok
# 218
# ok
# 219
# ok
# 220
# ok
# 221
# ok
# 222
# ok
# 223
# ok
# 224
# ok
# 225
# ok
# 226
# ok
# 227
# ok
# 228
# ok
# 229
# ok
# 230
# ok
# 231
# ok
# 232
# ok
# 233
# ok
# 234
# ok
# 235
# ok
# 236
# ok
# 237
# ok
# 238
# ok
# 239
# ok
# 240
# ok
# 241
# ok
# 242
# ok
# 243
# ok
# 244
# ok
# 245
# ok
# 246
# ok
# 247
# ok
# 248
# ok
# 249
# ok
# 250
# ok
# 251
# ok
# 252
# ok
# 253
# ok
# 254
# ok
# 255
# ok
# 256
# ok
# 257
# ok
# 258
# ok
# 259
# ok
# 260
# ok
# 261
# ok
# 262
# ok
# 263
# ok
# 264
# ok
# 265
# ok
# 266
# ok
# 267
# ok
# 268
# ok
# 269
# ok
# 270
# ok
# 271
# ok
# 272
# ok
# 273
# ok
# 274
# ok
# 275
# ok
# 276
# ok
# 277
# ok
# 278
# ok
# 279
# ok
# 280
# ok
# 281
# ok
# 282
# ok
# 283
# ok
# 284
# ok
# 285
# ok
# 286
# ok
# 287
# ok
# 288
# ok
# 289
# ok
# 290
# ok
# 291
# ok
# 292
# ok
# 293
# ok
# 294
# ok
# 295
# ok
# 296
# ok
# 297
# ok
# 298
# ok
# 299
# ok
# 300
# ok
# 301
# ok
# 302
# ok
# 303
# ok
# 304
# ok
# 305
# ok
# 306
# ok
# 307
# ok
# 308
# ok
# 309
# ok
# 310
# ok
# 311
# ok
# 312
# ok
# 313
# ok
# 314
# ok
# 315
# ok
# 316
# ok
# 317
# ok
# 318
# ok
# 319
# ok
# 320
# ok
# 321
# ok
# 322
# ok
# 323
# ok
# 324
# ok
# 325
# ok
# 326
# ok
# 327
# ok
# 328
# ok
# 329
# ok
# 330
# ok
# 331
# ok
# 332
# ok
# 333
# ok
# 334
# ok
# 335
# ok
# 336
# ok
# 337
# ok
# 338
# ok
# 339
# ok
# 340
# ok
# 341
# ok
# 342
# ok
# 343
# ok
# 344
# ok
# 345
# ok
# 346
# ok
# 347
# ok
# 348
# ok
# 349
# ok
# 350
# ok
# 351
# ok
# 352
# ok
# 353
# ok
# 354
# ok
# 355
# ok
# 356
# ok
# 357
# ok
# 358
# ok
# 359
# ok
# 360
# ok
# 361
# ok
# 362
# ok
# 363
# ok
# 364
# ok
# 365
# ok
# 366
# ok
# 367
# ok
# 368
# ok
# 369
# ok
# 370
# ok
# 371
# ok
# 372
# ok
# 373
# ok
# 374
# ok
# 375
# ok
# 376
# ok
# 377
# ok
# 378
# ok
# 379
# ok
# 380
# ok
# 381
# ok
# 382
# ok
# 383
# ok
# 384
# ok
# 385
# ok
# 386
# ok
# 387
# ok
# 388
# ok
# 389
# ok
# 390
# ok
# 391
# ok
# 392
# ok
# 393
# ok
# 394
# ok
# 395
# ok
# 396
# ok
# 397
# ok
# 398
# ok
# 399
# ok
# 400
# ok
# 401
# ok
# 402
# ok
# 403
# ok
# 404
# ok
# 405
# ok
# 406
# ok
# 407
# ok
# 408
# ok
# 409
# ok
# 410
# ok
# 411
# ok
# 412
# ok
# 413
# ok
# 414
# ok
# 415
# ok
# 416
# ok
# 417
# ok
# 418
# ok
# 419
# ok
# 420
# ok
# 421
# ok
# 422
# ok
# 423
# ok
# 424
# ok
# 425
# ok
# 426
# ok
# 427
# ok
# 428
# ok
# 429

# %%
df_final.to_csv('vivino.csv',index=False)

# %%
df_final.reset_index(drop=True,inplace=True)

# %%
isna=df_final.isna().sum()/df_final.shape[0]

# %%
isna[isna>0]
# Out:
# price                                            1.000000
# vintage.image.variations.bottle_large            0.006419
# vintage.image.variations.bottle_medium           0.006419
# vintage.image.variations.bottle_medium_square    0.006419
# vintage.image.variations.bottle_small            0.006419
#                                                    ...
# vintage.wine.style.background_image              1.000000
# vintage.wine.style.region.background_image       1.000000
# vintage.wine.taste.structure                     1.000000
# vintage.wine.style                               1.000000
# vintage.top_list_rankings                        0.968651
# Length: 81, dtype: float64

# %%
cols_to_drop=isna[isna==1].index

# %%
df_final.drop(cols_to_drop, axis=1, inplace=True)

# %%
isna=df_final.isna().sum()/df_final.shape[0]

# %%
isna[isna>0]
# Out:
# vintage.image.variations.bottle_large                           0.006419
# vintage.image.variations.bottle_medium                          0.006419
# vintage.image.variations.bottle_medium_square                   0.006419
# vintage.image.variations.bottle_small                           0.006419
# vintage.image.variations.bottle_small_square                    0.006419
#                                                                   ...
# vintage.wine.style.region.country.most_used_grapes              0.033767
# vintage.wine.style.region.background_image.location             0.056279
# vintage.wine.style.region.background_image.variations.large     0.056279
# vintage.wine.style.region.background_image.variations.medium    0.056279
# vintage.top_list_rankings                                       0.968651
# Length: 70, dtype: float64

# %%
df_final['vintage.image.variations.bottle_medium_square']
# Out:
# 0        //images.vivino.com/thumbs/vbOFe55ERWq9S4Ha1ZG...
# 1        //images.vivino.com/thumbs/rgfSN2TaTluKQDDGcd2...
# 2        //images.vivino.com/thumbs/sEtWZCfkQZCi0x8c_FA...
# 3        //images.vivino.com/thumbs/jlpH6WEtS0m2_Vu9RlB...
# 4        //images.vivino.com/thumbs/9WEOhwm9RgOOT6zDeiY...
#                                ...
# 10745    //images.vivino.com/thumbs/YELZlu1kRlG_JBI5l9L...
# 10746    //images.vivino.com/thumbs/Gb2ViEV1Sy6_7YsmFM9...
# 10747    //images.vivino.com/thumbs/QmQ_cg9ZS_6R1-5zc2X...
# 10748    //images.vivino.com/thumbs/3WgPGJ76SgezTzuTGzG...
# 10749    //images.vivino.com/thumbs/-_L58CMdSAOleMTV95j...
# Name: vintage.image.variations.bottle_medium_square, Length: 10750, dtype: object

# %%
def liste(c):
    N=[]
    for i in range(1,13):
        if i<10 :
            N.append(str(c)+str('-')+str(0)+str(i))
        else : 
            N.append(str(c)+str('-')+str(i))
    return N

def splitDataFrameList(df,target_column,separator):
    ''' df = dataframe to split,
    target_column = the column containing the values to split
    separator = the symbol used to perform the split
    returns: a dataframe with each entry for the target column separated, with each element moved into a new row. 
    The values in the other columns are duplicated across the newly divided rows.
    '''
    def splitListToRows(row,row_accumulator,target_column,separator):
        split_row = row[target_column]
        for s in split_row:
            new_row = row.to_dict()
            new_row[target_column] = s
            row_accumulator.append(new_row)
    new_rows = []
    df.apply(splitListToRows,axis=1,args = (new_rows,target_column,separator))
    new_df = pd.DataFrame(new_rows)
    return new_df

df_final['Year'] = df_final.apply(lambda row:(liste(row['vintage.year'])),axis=1)

df_final=splitDataFrameList(df=df_final, target_column="Year",separator=",")

# %%
df_final
# Out:
#        prices  vintage.id                                   vintage.seo_name  \
# 0          []   159817517        calmel-joseph-villa-blanche-chardonnay-2019
# 1          []   159817517        calmel-joseph-villa-blanche-chardonnay-2019
# 2          []   159817517        calmel-joseph-villa-blanche-chardonnay-2019
# 3          []   159817517        calmel-joseph-villa-blanche-chardonnay-2019
# 4          []   159817517        calmel-joseph-villa-blanche-chardonnay-2019
# ...       ...         ...                                                ...
# 128995     []   156226230  domaine-yves-cuilleron-condrieu-la-petite-cote...
# 128996     []   156226230  domaine-yves-cuilleron-condrieu-la-petite-cote...
# 128997     []   156226230  domaine-yves-cuilleron-condrieu-la-petite-cote...
# 128998     []   156226230  domaine-yves-cuilleron-condrieu-la-petite-cote...
# 128999     []   156226230  domaine-yves-cuilleron-condrieu-la-petite-cote...
#
#                                          vintage.name  \
# 0       Calmel & Joseph Villa Blanche Chardonnay 2019
# 1       Calmel & Joseph Villa Blanche Chardonnay 2019
# 2       Calmel & Joseph Villa Blanche Chardonnay 2019
# 3       Calmel & Joseph Villa Blanche Chardonnay 2019
# 4       Calmel & Joseph Villa Blanche Chardonnay 2019
# ...                                               ...
# 128995    Yves Cuilleron Condrieu La Petite Côte 2018
# 128996    Yves Cuilleron Condrieu La Petite Côte 2018
# 128997    Yves Cuilleron Condrieu La Petite Côte 2018
# 128998    Yves Cuilleron Condrieu La Petite Côte 2018
# 128999    Yves Cuilleron Condrieu La Petite Côte 2018
#
#        vintage.statistics.status  vintage.statistics.ratings_count  \
# 0                         Normal                                96
# 1                         Normal                                96
# 2                         Normal                                96
# 3                         Normal                                96
# 4                         Normal                                96
# ...                          ...                               ...
# 128995                    Normal                               133
# 128996                    Normal                               133
# 128997                    Normal                               133
# 128998                    Normal                               133
# 128999                    Normal                               133
#
#         vintage.statistics.ratings_average  vintage.statistics.labels_count  \
# 0                                      3.8                              193
# 1                                      3.8                              193
# 2                                      3.8                              193
# 3                                      3.8                              193
# 4                                      3.8                              193
# ...                                    ...                              ...
# 128995                                 4.1                              476
# 128996                                 4.1                              476
# 128997                                 4.1                              476
# 128998                                 4.1                              476
# 128999                                 4.1                              476
#
#                                    vintage.image.location  \
# 0       //images.vivino.com/thumbs/vbOFe55ERWq9S4Ha1ZG...
# 1       //images.vivino.com/thumbs/vbOFe55ERWq9S4Ha1ZG...
# 2       //images.vivino.com/thumbs/vbOFe55ERWq9S4Ha1ZG...
# 3       //images.vivino.com/thumbs/vbOFe55ERWq9S4Ha1ZG...
# 4       //images.vivino.com/thumbs/vbOFe55ERWq9S4Ha1ZG...
# ...                                                   ...
# 128995  //images.vivino.com/thumbs/-_L58CMdSAOleMTV95j...
# 128996  //images.vivino.com/thumbs/-_L58CMdSAOleMTV95j...
# 128997  //images.vivino.com/thumbs/-_L58CMdSAOleMTV95j...
# 128998  //images.vivino.com/thumbs/-_L58CMdSAOleMTV95j...
# 128999  //images.vivino.com/thumbs/-_L58CMdSAOleMTV95j...
#
#                     vintage.image.variations.bottle_large  ...  \
# 0       //images.vivino.com/thumbs/vbOFe55ERWq9S4Ha1ZG...  ...
# 1       //images.vivino.com/thumbs/vbOFe55ERWq9S4Ha1ZG...  ...
# 2       //images.vivino.com/thumbs/vbOFe55ERWq9S4Ha1ZG...  ...
# 3       //images.vivino.com/thumbs/vbOFe55ERWq9S4Ha1ZG...  ...
# 4       //images.vivino.com/thumbs/vbOFe55ERWq9S4Ha1ZG...  ...
# ...                                                   ...  ...
# 128995  //images.vivino.com/thumbs/-_L58CMdSAOleMTV95j...  ...
# 128996  //images.vivino.com/thumbs/-_L58CMdSAOleMTV95j...  ...
# 128997  //images.vivino.com/thumbs/-_L58CMdSAOleMTV95j...  ...
# 128998  //images.vivino.com/thumbs/-_L58CMdSAOleMTV95j...  ...
# 128999  //images.vivino.com/thumbs/-_L58CMdSAOleMTV95j...  ...
#
#        vintage.wine.style.region.country.wineries_count  \
# 0                                               64936.0
# 1                                               64936.0
# 2                                               64936.0
# 3                                               64936.0
# 4                                               64936.0
# ...                                                 ...
# 128995                                          64936.0
# 128996                                          64936.0
# 128997                                          64936.0
# 128998                                          64936.0
# 128999                                          64936.0
#
#        vintage.wine.style.region.country.most_used_grapes  \
# 0       [{'id': 14, 'name': 'Pinot Noir', 'seo_name': ...
# 1       [{'id': 14, 'name': 'Pinot Noir', 'seo_name': ...
# 2       [{'id': 14, 'name': 'Pinot Noir', 'seo_name': ...
# 3       [{'id': 14, 'name': 'Pinot Noir', 'seo_name': ...
# 4       [{'id': 14, 'name': 'Pinot Noir', 'seo_name': ...
# ...                                                   ...
# 128995  [{'id': 14, 'name': 'Pinot Noir', 'seo_name': ...
# 128996  [{'id': 14, 'name': 'Pinot Noir', 'seo_name': ...
# 128997  [{'id': 14, 'name': 'Pinot Noir', 'seo_name': ...
# 128998  [{'id': 14, 'name': 'Pinot Noir', 'seo_name': ...
# 128999  [{'id': 14, 'name': 'Pinot Noir', 'seo_name': ...
#
#        vintage.wine.style.region.background_image.location  \
# 0       //images.vivino.com/regions/backgrounds/-iw2xw...
# 1       //images.vivino.com/regions/backgrounds/-iw2xw...
# 2       //images.vivino.com/regions/backgrounds/-iw2xw...
# 3       //images.vivino.com/regions/backgrounds/-iw2xw...
# 4       //images.vivino.com/regions/backgrounds/-iw2xw...
# ...                                                   ...
# 128995                                                NaN
# 128996                                                NaN
# 128997                                                NaN
# 128998                                                NaN
# 128999                                                NaN
#
#        vintage.wine.style.region.background_image.variations.large  \
# 0       //thumbs.vivino.com/region_backgrounds/-iw2xwa...
# 1       //thumbs.vivino.com/region_backgrounds/-iw2xwa...
# 2       //thumbs.vivino.com/region_backgrounds/-iw2xwa...
# 3       //thumbs.vivino.com/region_backgrounds/-iw2xwa...
# 4       //thumbs.vivino.com/region_backgrounds/-iw2xwa...
# ...                                                   ...
# 128995                                                NaN
# 128996                                                NaN
# 128997                                                NaN
# 128998                                                NaN
# 128999                                                NaN
#
#        vintage.wine.style.region.background_image.variations.medium  \
# 0       //thumbs.vivino.com/region_backgrounds/-iw2xwa...
# 1       //thumbs.vivino.com/region_backgrounds/-iw2xwa...
# 2       //thumbs.vivino.com/region_backgrounds/-iw2xwa...
# 3       //thumbs.vivino.com/region_backgrounds/-iw2xwa...
# 4       //thumbs.vivino.com/region_backgrounds/-iw2xwa...
# ...                                                   ...
# 128995                                                NaN
# 128996                                                NaN
# 128997                                                NaN
# 128998                                                NaN
# 128999                                                NaN
#
#        vintage.wine.has_valid_ratings vintage.year vintage.has_valid_ratings  \
# 0                                True         2019                      True
# 1                                True         2019                      True
# 2                                True         2019                      True
# 3                                True         2019                      True
# 4                                True         2019                      True
# ...                               ...          ...                       ...
# 128995                           True         2018                      True
# 128996                           True         2018                      True
# 128997                           True         2018                      True
# 128998                           True         2018                      True
# 128999                           True         2018                      True
#
#        vintage.top_list_rankings     Year
# 0                            NaN  2019-01
# 1                            NaN  2019-02
# 2                            NaN  2019-03
# 3                            NaN  2019-04
# 4                            NaN  2019-05
# ...                          ...      ...
# 128995                       NaN  2018-08
# 128996                       NaN  2018-09
# 128997                       NaN  2018-10
# 128998                       NaN  2018-11
# 128999                       NaN  2018-12
#
# [129000 rows x 118 columns]

# %%
url
# Out:
# 'https://www.vivino.com/api/explore/explore?country_code=FR&country_codes[]=fr&currency_code=EUR&grape_filter=varietal&min_rating=1&order_by=discount_percent&order=desc&page=430&price_range_max=500&price_range_min=0'

# %%
url="https://www.vivino.com/api/explore/explore?country_code=FR&currency_code=EUR&grape_filter=varietal&min_rating=1&order_by=ratings_average&order=desc&page=2&price_range_max=500&price_range_min=1"

# %%
headers="""accept: application/json
accept-encoding: gzip, deflate, br
accept-language: en-US,en;q=0.9,fr;q=0.8
cache-control: no-cache
content-type: application/json
cookie: first_time_visit=SlE0K0R5TklKL3ZyVm1JUFJ2OVhFUT09LS0wRXNzRS9qNVJ4alpDVjl5ZExyS3VBPT0%3D--01435edc04b16b429c6077f0779acd48b95037e7; client_cache_key=ajJjaURpMG9nZlhSSnFaU04xSHg3blNndGljSDFFRjJ4WUF0cnFhYnlSND0tLUwzOWpBdlFEVGdKZ3AvdVg3VlkvU1E9PQ%3D%3D--29d95ef61d4568eb6bf5c24d4fa9c1be1cae48e3; _ga=GA1.2.162712669.1597143251; _gid=GA1.2.290464444.1597143251; _gat_vivinoTracker=1; _ruby-web_session=...--577b0df633a91c31850b1f6bfac193d635e7179a
dnt: 1
pragma: no-cache
referer: https://www.vivino.com/explore?e=eJzLLbI11jNVy83MszVXy02ssDU2UEuutHULUku2dQ0NUiuwNVRLT7MtSyzKTC1JzFHLT7ItSizJzEsvjk8sSy1KTE9Vy7dNSS1OVisviY4FKgZTRgDL1Bz4
sec-fetch-dest: empty
sec-fetch-mode: cors
sec-fetch-site: same-origin
user-agent: Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/81.0.4044.138 Safari/537.36 OPR/68.0.3618.206
x-requested-with: XMLHttpRequest"""

# %%
headers=dict([i.strip().split(': ') for i in headers.split('\n')])
resp=r.get(url, headers=headers)

# %%
resp=resp.json()['explore_vintage']

# %%
resp.keys()
# Out:
# dict_keys(['market', 'records_matched', 'matches', 'bottle_type_errors', 'records'])

# %%
pd.json_normalize(resp['matches'])
# Out:
#                                                prices  vintage.id  \
# 0   [{'id': 19975285, 'amount': 9802, 'discounted_...     1488129
# 1   [{'id': 19975379, 'amount': 12475, 'discounted...     4492471
# 2   [{'id': 21604497, 'amount': 92, 'discounted_fr...   156316766
# 3   [{'id': 8697771, 'amount': 620, 'discounted_fr...     1791320
# 4   [{'id': 10931340, 'amount': 750, 'discounted_f...    10381434
# 5   [{'id': 19975321, 'amount': 7129, 'discounted_...     5413570
# 6   [{'id': 18626369, 'amount': 270, 'discounted_f...    58920197
# 7   [{'id': 8598834, 'amount': 1090, 'discounted_f...      753089
# 8   [{'id': 22360649, 'amount': 320, 'discounted_f...   163422370
# 9   [{'id': 17466893, 'amount': 3822.3333333333335...     2967858
# 10  [{'id': 17709161, 'amount': 1160, 'discounted_...     2386274
# 11  [{'id': 15274024, 'amount': 1670, 'discounted_...   146289252
# 12  [{'id': 21382993, 'amount': 6029.333333333333,...     3791418
# 13  [{'id': 17676436, 'amount': 607, 'discounted_f...    39507540
# 14  [{'id': 20415816, 'amount': 390, 'discounted_f...     3564925
# 15  [{'id': 17629358, 'amount': 432, 'discounted_f...       87403
# 16  [{'id': 13243115, 'amount': 350, 'discounted_f...     1390988
# 17  [{'id': 14792514, 'amount': 330, 'discounted_f...       82142
# 18  [{'id': 17220513, 'amount': 410, 'discounted_f...     1830567
# 19  [{'id': 17007970, 'amount': 525.4166666666666,...     1334808
# 20  [{'id': 17009389, 'amount': 587.75, 'discounte...     3360141
# 21  [{'id': 14169267, 'amount': 360, 'discounted_f...     1207347
# 22  [{'id': 20570577, 'amount': 1439.4, 'discounte...     3909022
# 23  [{'id': 17636906, 'amount': 229.17999999999998...     1347152
# 24  [{'id': 17008070, 'amount': 388.4166666666667,...     1436268
#
#                                      vintage.seo_name  \
# 0   domaine-de-la-romanee-conti-montrachet-grand-c...
# 1   domaine-de-la-romanee-conti-montrachet-grand-c...
# 2                  chateau-d-esclans-garrus-rose-2018
# 3          quinta-do-noval-vintage-port-nacional-2001
# 4                                   bond-st-eden-2014
# 5   domaine-coche-dury-corton-charlemagne-grand-cr...
# 6      taylors-port-very-old-single-harvest-port-1969
# 7          quinta-do-noval-vintage-port-nacional-2000
# 8          sine-qua-non-gorgeous-victim-grenache-2017
# 9                                 le-pin-pomerol-2002
# 10  haut-brion-pessac-leognan-blanc-grand-cru-clas...
# 11  dom-perignon-p2-plenitude-brut-rose-champagne-...
# 12                                le-pin-pomerol-2010
# 13                    dalla-valle-vineyards-maya-2015
# 14  champagne-billecart-salmon-clos-saint-hilaire-...
# 15                            vega-sicilia-unico-2004
# 16                            vega-sicilia-unico-2005
# 17  louis-roederer-cristal-brut-champagne-millesim...
# 18  chateau-d-yquem-sauternes-sauternes-dessert-wi...
# 19  chateau-d-yquem-sauternes-sauternes-dessert-wi...
# 20                             opus-one-opus-one-2007
# 21                            vega-sicilia-unico-2008
# 22  chateau-mouton-rothschild-pauillac-premier-gra...
# 23  chateau-pontet-canet-pauillac-grand-cru-classe...
# 24  chateau-d-yquem-sauternes-sauternes-dessert-wi...
#
#                                          vintage.name  \
# 0   Domaine de La Romanée-Conti Montrachet Grand C...
# 1   Domaine de La Romanée-Conti Montrachet Grand C...
# 2                  Château d'Esclans Garrus Rosé 2018
# 3          Quinta do Noval Vintage Port Nacional 2001
# 4                                  Bond St. Eden 2014
# 5   Domaine Coche-Dury Corton-Charlemagne Grand Cr...
# 6          Taylor's Very Old Single Harvest Port 1969
# 7          Quinta do Noval Vintage Port Nacional 2000
# 8          Sine Qua Non Gorgeous Victim Grenache 2017
# 9                                 Le Pin Pomerol 2002
# 10  Château Haut-Brion Pessac-Léognan Blanc (Grand...
# 11  Dom Pérignon P2 Plénitude Brut Rosé Champagne ...
# 12                                Le Pin Pomerol 2010
# 13                              Dalla Valle Maya 2015
# 14  Billecart-Salmon Clos Saint-Hilaire Brut Champ...
# 15                            Vega Sicilia Unico 2004
# 16                            Vega Sicilia Unico 2005
# 17  Louis Roederer Cristal Brut Champagne (Millési...
# 18                     Château d'Yquem Sauternes 1996
# 19                     Château d'Yquem Sauternes 1998
# 20                             Opus One Opus One 2007
# 21                            Vega Sicilia Unico 2008
# 22  Château Mouton Rothschild Pauillac (Premier Gr...
# 23  Château Pontet-Canet Pauillac (Grand Cru Class...
# 24                     Château d'Yquem Sauternes 1999
#
#    vintage.statistics.status  vintage.statistics.ratings_count  \
# 0                     Normal                                28
# 1                     Normal                                53
# 2                     Normal                                44
# 3                     Normal                                42
# 4                     Normal                                40
# 5                     Normal                                38
# 6                     Normal                                38
# 7                     Normal                                38
# 8                     Normal                                37
# 9                     Normal                                33
# 10                    Normal                                32
# 11                    Normal                                31
# 12                    Normal                                31
# 13                    Normal                                28
# 14                    Normal                                55
# 15                    Normal                              2797
# 16                    Normal                              2677
# 17                    Normal                              2626
# 18                    Normal                              2422
# 19                    Normal                              2326
# 20                    Normal                              2261
# 21                    Normal                              2146
# 22                    Normal                              1925
# 23                    Normal                              1911
# 24                    Normal                              1894
#
#     vintage.statistics.ratings_average  vintage.statistics.labels_count  \
# 0                                  4.8                              200
# 1                                  4.8                              312
# 2                                  4.8                              238
# 3                                  4.8                              153
# 4                                  4.8                              227
# 5                                  4.8                              170
# 6                                  4.8                              112
# 7                                  4.8                              121
# 8                                  4.8                              163
# 9                                  4.8                              165
# 10                                 4.8                               88
# 11                                 4.8                               45
# 12                                 4.8                              171
# 13                                 4.8                              187
# 14                                 4.8                              180
# 15                                 4.7                            12984
# 16                                 4.7                            15724
# 17                                 4.7                            12617
# 18                                 4.7                            10650
# 19                                 4.7                             9896
# 20                                 4.7                            10718
# 21                                 4.7                            13358
# 22                                 4.7                            13579
# 23                                 4.7                            14852
# 24                                 4.7                             8436
#
#                                vintage.image.location  \
# 0   //images.vivino.com/thumbs/rORmihtxSrKG7SfuI0b...
# 1   //images.vivino.com/thumbs/rORmihtxSrKG7SfuI0b...
# 2   //images.vivino.com/thumbs/1Y51IHj7STqf2CJv72y...
# 3   //images.vivino.com/thumbs/Dc4oCLqGQemNRNwH4Kj...
# 4   //images.vivino.com/thumbs/0b4-sfABS6W7mt_rr4V...
# 5   //images.vivino.com/thumbs/QIs0hHhdRHubnyUjY8U...
# 6   //images.vivino.com/thumbs/PSZoUaADSUSJXu4MKQo...
# 7   //images.vivino.com/thumbs/Dc4oCLqGQemNRNwH4Kj...
# 8   //images.vivino.com/thumbs/KKN7QTyzROKQ1tOpYk0...
# 9   //images.vivino.com/thumbs/rCirPraNRPy8PHfOlG4...
# 10  //images.vivino.com/thumbs/EvtJOugzTx-HZXZfdZv...
# 11  //images.vivino.com/thumbs/qYsRxC1qRY-Xvu6VmhM...
# 12  //images.vivino.com/thumbs/rCirPraNRPy8PHfOlG4...
# 13  //images.vivino.com/thumbs/PRsJ-uaoSs-KodkrzRy...
# 14  //images.vivino.com/thumbs/qsDV-1yaSWi6OmT2Fm1...
# 15  //images.vivino.com/thumbs/SCnpJk_ySUe6XS3U-lF...
# 16  //images.vivino.com/thumbs/SCnpJk_ySUe6XS3U-lF...
# 17  //images.vivino.com/thumbs/bXZK_MhMQi-a2xrjEIT...
# 18  //images.vivino.com/thumbs/Jt7xLGXcSA22gVYMyBJ...
# 19  //images.vivino.com/thumbs/Jt7xLGXcSA22gVYMyBJ...
# 20  //images.vivino.com/thumbs/C45ybDUxTnWShRkbSTu...
# 21  //images.vivino.com/thumbs/SCnpJk_ySUe6XS3U-lF...
# 22  //images.vivino.com/thumbs/2IQ2yluISw2JkjYh81D...
# 23  //images.vivino.com/thumbs/zoXYIDxFQzmf8fFpkNN...
# 24  //images.vivino.com/thumbs/Jt7xLGXcSA22gVYMyBJ...
#
#                 vintage.image.variations.bottle_large  ...  \
# 0   //images.vivino.com/thumbs/rORmihtxSrKG7SfuI0b...  ...
# 1   //images.vivino.com/thumbs/rORmihtxSrKG7SfuI0b...  ...
# 2   //images.vivino.com/thumbs/1Y51IHj7STqf2CJv72y...  ...
# 3   //images.vivino.com/thumbs/Dc4oCLqGQemNRNwH4Kj...  ...
# 4   //images.vivino.com/thumbs/0b4-sfABS6W7mt_rr4V...  ...
# 5   //images.vivino.com/thumbs/QIs0hHhdRHubnyUjY8U...  ...
# 6   //images.vivino.com/thumbs/PSZoUaADSUSJXu4MKQo...  ...
# 7   //images.vivino.com/thumbs/Dc4oCLqGQemNRNwH4Kj...  ...
# 8   //images.vivino.com/thumbs/KKN7QTyzROKQ1tOpYk0...  ...
# 9   //images.vivino.com/thumbs/rCirPraNRPy8PHfOlG4...  ...
# 10  //images.vivino.com/thumbs/EvtJOugzTx-HZXZfdZv...  ...
# 11  //images.vivino.com/thumbs/qYsRxC1qRY-Xvu6VmhM...  ...
# 12  //images.vivino.com/thumbs/rCirPraNRPy8PHfOlG4...  ...
# 13  //images.vivino.com/thumbs/PRsJ-uaoSs-KodkrzRy...  ...
# 14  //images.vivino.com/thumbs/qsDV-1yaSWi6OmT2Fm1...  ...
# 15  //images.vivino.com/thumbs/SCnpJk_ySUe6XS3U-lF...  ...
# 16  //images.vivino.com/thumbs/SCnpJk_ySUe6XS3U-lF...  ...
# 17  //images.vivino.com/thumbs/bXZK_MhMQi-a2xrjEIT...  ...
# 18  //images.vivino.com/thumbs/Jt7xLGXcSA22gVYMyBJ...  ...
# 19  //images.vivino.com/thumbs/Jt7xLGXcSA22gVYMyBJ...  ...
# 20  //images.vivino.com/thumbs/C45ybDUxTnWShRkbSTu...  ...
# 21  //images.vivino.com/thumbs/SCnpJk_ySUe6XS3U-lF...  ...
# 22  //images.vivino.com/thumbs/2IQ2yluISw2JkjYh81D...  ...
# 23  //images.vivino.com/thumbs/zoXYIDxFQzmf8fFpkNN...  ...
# 24  //images.vivino.com/thumbs/Jt7xLGXcSA22gVYMyBJ...  ...
#
#    price.bottle_type.short_name price.bottle_type.short_name_plural  \
# 0                     bouteille                          bouteilles
# 1                     bouteille                          bouteilles
# 2                     bouteille                          bouteilles
# 3                     bouteille                          bouteilles
# 4                     bouteille                          bouteilles
# 5                     bouteille                          bouteilles
# 6                     bouteille                          bouteilles
# 7                     bouteille                          bouteilles
# 8                     bouteille                          bouteilles
# 9                     bouteille                          bouteilles
# 10                    bouteille                          bouteilles
# 11                    bouteille                          bouteilles
# 12                    bouteille                          bouteilles
# 13                    bouteille                          bouteilles
# 14                    bouteille                          bouteilles
# 15                    bouteille                          bouteilles
# 16                    bouteille                          bouteilles
# 17                    bouteille                          bouteilles
# 18                    bouteille                          bouteilles
# 19                    bouteille                          bouteilles
# 20                    bouteille                          bouteilles
# 21                    bouteille                          bouteilles
# 22                    bouteille                          bouteilles
# 23                    bouteille                          bouteilles
# 24                    bouteille                          bouteilles
#
#    price.bottle_type.volume_ml  \
# 0                          750
# 1                          750
# 2                          750
# 3                          750
# 4                          750
# 5                          750
# 6                          750
# 7                          750
# 8                          750
# 9                          750
# 10                         750
# 11                         750
# 12                         750
# 13                         750
# 14                         750
# 15                         750
# 16                         750
# 17                         750
# 18                         750
# 19                         750
# 20                         750
# 21                         750
# 22                         750
# 23                         750
# 24                         750
#
#         vintage.wine.region.background_image.location  \
# 0                                                 NaN
# 1                                                 NaN
# 2   //images.vivino.com/regions/backgrounds/f6SgQn...
# 3   //images.vivino.com/regions/backgrounds/iC_qG6...
# 4   //images.vivino.com/regions/backgrounds/cP8NlY...
# 5                                                 NaN
# 6   //images.vivino.com/regions/backgrounds/iC_qG6...
# 7   //images.vivino.com/regions/backgrounds/iC_qG6...
# 8   //images.vivino.com/regions/backgrounds/HNZzLu...
# 9   //images.vivino.com/regions/backgrounds/OWIaZW...
# 10  //images.vivino.com/regions/backgrounds/yXeD5e...
# 11  //images.vivino.com/regions/backgrounds/pDAYNE...
# 12  //images.vivino.com/regions/backgrounds/OWIaZW...
# 13  //images.vivino.com/regions/backgrounds/ctOdB-...
# 14  //images.vivino.com/regions/backgrounds/pDAYNE...
# 15  //images.vivino.com/regions/backgrounds/YX2wax...
# 16  //images.vivino.com/regions/backgrounds/YX2wax...
# 17  //images.vivino.com/regions/backgrounds/pDAYNE...
# 18  //images.vivino.com/regions/backgrounds/NOjj4x...
# 19  //images.vivino.com/regions/backgrounds/NOjj4x...
# 20  //images.vivino.com/regions/backgrounds/cP8NlY...
# 21  //images.vivino.com/regions/backgrounds/YX2wax...
# 22  //images.vivino.com/regions/backgrounds/-wJ76B...
# 23  //images.vivino.com/regions/backgrounds/-wJ76B...
# 24  //images.vivino.com/regions/backgrounds/NOjj4x...
#
#    vintage.wine.region.background_image.variations.large  \
# 0                                                 NaN
# 1                                                 NaN
# 2   //thumbs.vivino.com/region_backgrounds/f6SgQnC...
# 3   //thumbs.vivino.com/region_backgrounds/iC_qG6i...
# 4   //thumbs.vivino.com/region_backgrounds/cP8NlYV...
# 5                                                 NaN
# 6   //thumbs.vivino.com/region_backgrounds/iC_qG6i...
# 7   //thumbs.vivino.com/region_backgrounds/iC_qG6i...
# 8   //thumbs.vivino.com/region_backgrounds/HNZzLu5...
# 9   //thumbs.vivino.com/region_backgrounds/OWIaZWe...
# 10  //thumbs.vivino.com/region_backgrounds/yXeD5eT...
# 11  //thumbs.vivino.com/region_backgrounds/pDAYNER...
# 12  //thumbs.vivino.com/region_backgrounds/OWIaZWe...
# 13  //thumbs.vivino.com/region_backgrounds/ctOdB-O...
# 14  //thumbs.vivino.com/region_backgrounds/pDAYNER...
# 15  //thumbs.vivino.com/region_backgrounds/YX2waxK...
# 16  //thumbs.vivino.com/region_backgrounds/YX2waxK...
# 17  //thumbs.vivino.com/region_backgrounds/pDAYNER...
# 18  //thumbs.vivino.com/region_backgrounds/NOjj4xP...
# 19  //thumbs.vivino.com/region_backgrounds/NOjj4xP...
# 20  //thumbs.vivino.com/region_backgrounds/cP8NlYV...
# 21  //thumbs.vivino.com/region_backgrounds/YX2waxK...
# 22  //thumbs.vivino.com/region_backgrounds/-wJ76BS...
# 23  //thumbs.vivino.com/region_backgrounds/-wJ76BS...
# 24  //thumbs.vivino.com/region_backgrounds/NOjj4xP...
#
#    vintage.wine.region.background_image.variations.medium  \
# 0                                                 NaN
# 1                                                 NaN
# 2   //thumbs.vivino.com/region_backgrounds/f6SgQnC...
# 3   //thumbs.vivino.com/region_backgrounds/iC_qG6i...
# 4   //thumbs.vivino.com/region_backgrounds/cP8NlYV...
# 5                                                 NaN
# 6   //thumbs.vivino.com/region_backgrounds/iC_qG6i...
# 7   //thumbs.vivino.com/region_backgrounds/iC_qG6i...
# 8   //thumbs.vivino.com/region_backgrounds/HNZzLu5...
# 9   //thumbs.vivino.com/region_backgrounds/OWIaZWe...
# 10  //thumbs.vivino.com/region_backgrounds/yXeD5eT...
# 11  //thumbs.vivino.com/region_backgrounds/pDAYNER...
# 12  //thumbs.vivino.com/region_backgrounds/OWIaZWe...
# 13  //thumbs.vivino.com/region_backgrounds/ctOdB-O...
# 14  //thumbs.vivino.com/region_backgrounds/pDAYNER...
# 15  //thumbs.vivino.com/region_backgrounds/YX2waxK...
# 16  //thumbs.vivino.com/region_backgrounds/YX2waxK...
# 17  //thumbs.vivino.com/region_backgrounds/pDAYNER...
# 18  //thumbs.vivino.com/region_backgrounds/NOjj4xP...
# 19  //thumbs.vivino.com/region_backgrounds/NOjj4xP...
# 20  //thumbs.vivino.com/region_backgrounds/cP8NlYV...
# 21  //thumbs.vivino.com/region_backgrounds/YX2waxK...
# 22  //thumbs.vivino.com/region_backgrounds/-wJ76BS...
# 23  //thumbs.vivino.com/region_backgrounds/-wJ76BS...
# 24  //thumbs.vivino.com/region_backgrounds/NOjj4xP...
#
#          vintage.wine.style.background_image.location  \
# 0                                                 NaN
# 1                                                 NaN
# 2   //images.vivino.com/backgrounds/styles/BDdC5nf...
# 3                                                 NaN
# 4   //images.vivino.com/backgrounds/styles/3834dkd...
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8   //images.vivino.com/backgrounds/styles/f-CbTZS...
# 9   //images.vivino.com/backgrounds/styles/DPkUPwi...
# 10                                                NaN
# 11  //images.vivino.com/backgrounds/styles/EDYJVTj...
# 12  //images.vivino.com/backgrounds/styles/DPkUPwi...
# 13  //images.vivino.com/backgrounds/styles/lkl1g1A...
# 14  //images.vivino.com/backgrounds/styles/EDYJVTj...
# 15  //images.vivino.com/backgrounds/styles/jvbiWuq...
# 16  //images.vivino.com/backgrounds/styles/jvbiWuq...
# 17  //images.vivino.com/backgrounds/styles/EDYJVTj...
# 18                                                NaN
# 19                                                NaN
# 20  //images.vivino.com/backgrounds/styles/lkl1g1A...
# 21  //images.vivino.com/backgrounds/styles/jvbiWuq...
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
#
#    vintage.wine.style.background_image.variations.small  \
# 0                                                 NaN
# 1                                                 NaN
# 2   //images.vivino.com/backgrounds/styles/thumbs/...
# 3                                                 NaN
# 4   //images.vivino.com/backgrounds/styles/thumbs/...
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8   //images.vivino.com/backgrounds/styles/thumbs/...
# 9   //images.vivino.com/backgrounds/styles/thumbs/...
# 10                                                NaN
# 11  //images.vivino.com/backgrounds/styles/thumbs/...
# 12  //images.vivino.com/backgrounds/styles/thumbs/...
# 13  //images.vivino.com/backgrounds/styles/thumbs/...
# 14  //images.vivino.com/backgrounds/styles/thumbs/...
# 15  //images.vivino.com/backgrounds/styles/thumbs/...
# 16  //images.vivino.com/backgrounds/styles/thumbs/...
# 17  //images.vivino.com/backgrounds/styles/thumbs/...
# 18                                                NaN
# 19                                                NaN
# 20  //images.vivino.com/backgrounds/styles/thumbs/...
# 21  //images.vivino.com/backgrounds/styles/thumbs/...
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
#
#    vintage.wine.taste.structure  \
# 0                           NaN
# 1                           NaN
# 2                           NaN
# 3                           NaN
# 4                           NaN
# 5                           NaN
# 6                           NaN
# 7                           NaN
# 8                           NaN
# 9                           NaN
# 10                          NaN
# 11                          NaN
# 12                          NaN
# 13                          NaN
# 14                          NaN
# 15                          NaN
# 16                          NaN
# 17                          NaN
# 18                          NaN
# 19                          NaN
# 20                          NaN
# 21                          NaN
# 22                          NaN
# 23                          NaN
# 24                          NaN
#
#                             vintage.top_list_rankings
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22  [{'rank': 4, 'previous_rank': 4, 'description'...
# 23  [{'rank': 5, 'previous_rank': 5, 'description'...
# 24                                                NaN
#
# [25 rows x 144 columns]

# %%
resp['matches'][0]['vintage'].keys()
# Out:
# dict_keys(['id', 'seo_name', 'name', 'statistics', 'image', 'wine', 'year', 'grapes', 'has_valid_ratings'])
