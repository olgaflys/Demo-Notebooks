# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#JSON-insights" data-toc-modified-id="JSON-insights-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>JSON insights</a></span><ul class="toc-item"><li><span><a href="#random" data-toc-modified-id="random-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>random</a></span></li><li><span><a href="#JSON-TREE" data-toc-modified-id="JSON-TREE-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>JSON TREE</a></span></li></ul></li><li><span><a href="#Table-generation" data-toc-modified-id="Table-generation-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Table generation</a></span><ul class="toc-item"><li><span><a href="#Wines" data-toc-modified-id="Wines-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Wines</a></span></li><li><span><a href="#sm" data-toc-modified-id="sm-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>sm</a></span></li></ul></li></ul></div>

# %%
import os

# %%
import pandas as pd

# %%
import pickle

# %%
los = []
with (open("vivino_scripts.pkl", "rb")) as openfile:
    while True:
        try:
            los=pickle.load(openfile)
        except EOFError:
            break

# %%
import re
import json

# %%
los=[json.loads(re.findall(r'window.__PRELOADED_STATE__.+?= (\{\".*?\});?\n',i)[0]) for i in los]

# %%
import random

# %%
random_index=random.sample(range(len(los)),1)[0]

# %%
sample=los[random_index]

# %% [markdown]
# # JSON insights

# %% [markdown]
# ## random

# %%
max((len(i.keys()) for i in los))
# Out:
# 12

# %%
min((len(i.keys()) for i in los))
# Out:
# 12

# %%
list_of_keys_1=los[0].keys()

# %%
list_of_keys_1
# Out:
# dict_keys(['vintage', 'price', 'highlights', 'merchant', 'shipping_message', 'sold_out', 'available_vintage_year', 'carts', 'prices_and_availability', 'basic_user_vintage', 'price_range', 'is_deal_page'])

# %%
max((len(i['vintage'].keys()) for i in los))
# Out:
# 22

# %%
min((len(i['vintage'].keys()) for i in los))
# Out:
# 21

# %%
los[0].keys()
# Out:
# dict_keys(['vintage', 'price', 'highlights', 'merchant', 'shipping_message', 'sold_out', 'available_vintage_year', 'carts', 'prices_and_availability', 'basic_user_vintage', 'price_range', 'is_deal_page'])

# %%
sample.keys()
# Out:
# dict_keys(['vintage', 'price', 'highlights', 'merchant', 'shipping_message', 'sold_out', 'available_vintage_year', 'carts', 'prices_and_availability', 'basic_user_vintage', 'price_range', 'is_deal_page'])

# %%
def enjoy(l):
    print('\n'.join(['- '+i+f' {str(type(l[i]))[8:-2]}' for i in l.keys()]))
    return None

# %%
str(type(sample['vintage']['statistics']))[8:-2]
# Out:
# 'dict'

# %%
enjoy(sample['price_range']['defaults'])
# Out:
# - minimum int
# - maximum int
# - currency_code str

# %% [markdown]
# ## JSON TREE

# %%
with open('wines_vivino.txt','r') as f:
    lurl=f.readlines()

# %%
print('https://www.vivino.com'+lurl[random_index])
# Out:
# https://www.vivino.com/chateau-pedesclaux-pauillac-grand-cru-classe/w/48994?year=2010&price_id=17010387

# %%
{i['vintage']['wine']['is_first_wine'] for i in los}
# Out:
# {False, True}

# %%
list_of_style_id=[i['vintage']['wine']['style']['id'] if i['vintage']['wine']['style'] else -1000 for i in los]
dict(sorted({i:list_of_style_id.count(i) for i in list_of_style_id}.items(), key=lambda x:x[1]))
# Out:
# {81: 1,
#  239: 1,
#  157: 1,
#  159: 1,
#  34: 1,
#  149: 1,
#  92: 1,
#  274: 1,
#  134: 1,
#  67: 1,
#  272: 1,
#  234: 1,
#  16: 1,
#  52: 1,
#  174: 1,
#  143: 1,
#  207: 1,
#  61: 1,
#  243: 1,
#  137: 1,
#  244: 1,
#  153: 1,
#  122: 2,
#  57: 2,
#  32: 2,
#  163: 2,
#  192: 2,
#  83: 2,
#  247: 2,
#  105: 2,
#  1: 2,
#  29: 2,
#  30: 2,
#  96: 2,
#  23: 2,
#  286: 2,
#  283: 2,
#  296: 2,
#  121: 2,
#  251: 2,
#  237: 3,
#  48: 3,
#  28: 3,
#  45: 3,
#  236: 3,
#  60: 3,
#  295: 3,
#  214: 3,
#  104: 3,
#  39: 4,
#  176: 4,
#  248: 4,
#  6: 4,
#  284: 4,
#  287: 4,
#  285: 4,
#  260: 4,
#  135: 4,
#  98: 5,
#  11: 5,
#  70: 5,
#  24: 5,
#  288: 5,
#  186: 5,
#  130: 6,
#  42: 7,
#  8: 7,
#  298: 7,
#  209: 8,
#  299: 8,
#  202: 9,
#  128: 9,
#  181: 10,
#  233: 10,
#  290: 11,
#  21: 11,
#  289: 12,
#  297: 14,
#  14: 15,
#  7: 17,
#  235: 17,
#  180: 18,
#  22: 19,
#  3: 21,
#  5: 21,
#  208: 23,
#  226: 24,
#  94: 25,
#  -1000: 41,
#  301: 42,
#  162: 65,
#  9: 72,
#  268: 72,
#  171: 73,
#  49: 82,
#  190: 90,
#  19: 93,
#  69: 99,
#  212: 101,
#  292: 135,
#  266: 178,
#  261: 181,
#  267: 186,
#  263: 235,
#  262: 249,
#  276: 323,
#  265: 358,
#  264: 445}

# %%
for i in los:
    x=i['vintage']['wine']['style']
    if x:
        if x['id']==274:
            break

# %%
x
# Out:
# {'id': 274,
#  'seo_name': 'loire-muscadet-muscadet',
#  'regional_name': 'Muscadet (Loire)',
#  'varietal_name': 'Muscadet',
#  'name': 'Muscadet (Loire)',
#  'image': None,
#  'background_image': None,
#  'description': 'Muscadet is a light-bodied, dry white wine made from Melon de Bourgogne grapes that impart lemon, lime, green apple and pear flavors. This highly-acidic wine—also known for mineral and salty characteristics—is meant to be consumed young, and pairs well with seafood (a classic pairing is oysters).\n\nRicher, creamier and more complex versions of Muscadet are also produced using winemaking techniques such as barrel fermentation and sur lie aging, which means the wine is left to age on the lees (expired yeast cells) after fermentation without filtering out the yeast sediment--a winemaking method that imparts a richer, creamier texture.\n\nMelon de Bourgogne grows in the Muscadet appellation in the Pays Nantais of Lower Loire Valley near the Loire River in western France.\n\nIn 2011, a cru communaux system was developed in the Muscadet appellation to designate superior growing regions within the appellation. The first three named were Clisson, Le Pallet and Gorges.',
#  'blurb': None,
#  'interesting_facts': ["D'après les lois françaises d'Appellation d'Origine Contrôlée, tous les Muscadet doivent être faibles en alcool — en dessous de 12% d'APV",
#   'Le Muscadet est le vin blanc initialement utilisé dans la recette traditionnelle française de la sauce au beurre blanc.',
#   "Comme son nom l'indique, le Melon de Bourgogne est originaire de Bourgogne, mais il n'est plus utilisé dans cette région depuis des siècles. Durant ce temps, certains producteurs ont créé une certaine confusion avec le Chardonnay, et c'est pourquoi il en reste toujours un peu en Côte d'Or."],
#  'body': 2,
#  'body_description': 'Léger',
#  'acidity': 3,
#  'acidity_description': 'Élevée',
#  'country': {'code': 'fr',
#   'name': 'France',
#   'native_name': 'France',
#   'seo_name': 'france',
#   'currency': {'code': 'EUR', 'name': 'Euros', 'prefix': '€', 'suffix': None},
#   'regions_count': 1280,
#   'users_count': 3790550,
#   'wines_count': 481923,
#   'wineries_count': 64952,
#   'most_used_grapes': [{'id': 14,
#     'name': 'Pinot Noir',
#     'seo_name': 'pinot-noir',
#     'has_detailed_info': True,
#     'wines_count': 462117},
#    {'id': 10,
#     'name': 'Merlot',
#     'seo_name': 'merlot',
#     'has_detailed_info': True,
#     'wines_count': 461197},
#    {'id': 5,
#     'name': 'Chardonnay',
#     'seo_name': 'chardonnay',
#     'has_detailed_info': True,
#     'wines_count': 487962}]},
#  'wine_type_id': 2,
#  'food': [{'id': 13,
#    'name': 'Shellfish',
#    'background_image': {'location': '//images.vivino.com/backgrounds/foods/13_shellfish.png',
#     'variations': {'small': '//images.vivino.com/backgrounds/foods/thumbs/13_shellfish_932x810.png'}},
#    'seo_name': 'shellfish'},
#   {'id': 27,
#    'name': 'Appetizers and snacks',
#    'background_image': {'location': '//images.vivino.com/backgrounds/foods/27_appetizers-snacks.png',
#     'variations': {'small': '//images.vivino.com/backgrounds/foods/thumbs/27_appetizers-snacks_932x810.png'}},
#    'seo_name': None},
#   {'id': 28,
#    'name': 'Lean fish',
#    'background_image': {'location': '//images.vivino.com/backgrounds/foods/28_leanfish.png',
#     'variations': {'small': '//images.vivino.com/backgrounds/foods/thumbs/28_leanfish_932x810.png'}},
#    'seo_name': None},
#   {'id': 40,
#    'name': 'Aperitif',
#    'background_image': {'location': '//images.vivino.com/backgrounds/foods/40_aperitif.png',
#     'variations': {'small': '//images.vivino.com/backgrounds/foods/thumbs/40_aperitif_932x810.png'}},
#    'seo_name': None}],
#  'grapes': [{'id': 1670,
#    'name': 'Melon de Bourgogne',
#    'seo_name': 'melon-de-bourgogne',
#    'has_detailed_info': False,
#    'wines_count': 3732}],
#  'region': {'id': 729,
#   'name': 'Loire Valley',
#   'name_en': 'Val de Loire',
#   'seo_name': 'loire-valley',
#   'country': {'code': 'fr',
#    'name': 'France',
#    'native_name': 'France',
#    'seo_name': 'france',
#    'currency': {'code': 'EUR', 'name': 'Euros', 'prefix': '€', 'suffix': None},
#    'regions_count': 1280,
#    'users_count': 3790550,
#    'wines_count': 481923,
#    'wineries_count': 64952,
#    'most_used_grapes': [{'id': 14,
#      'name': 'Pinot Noir',
#      'seo_name': 'pinot-noir',
#      'has_detailed_info': True,
#      'wines_count': 462117},
#     {'id': 10,
#      'name': 'Merlot',
#      'seo_name': 'merlot',
#      'has_detailed_info': True,
#      'wines_count': 461197},
#     {'id': 5,
#      'name': 'Chardonnay',
#      'seo_name': 'chardonnay',
#      'has_detailed_info': True,
#      'wines_count': 487962}]},
#   'background_image': {'location': '//images.vivino.com/regions/backgrounds/9lP_DxrNQnuADJ7Hv4SYuA.jpg',
#    'variations': {'large': '//thumbs.vivino.com/region_backgrounds/9lP_DxrNQnuADJ7Hv4SYuA_1280x760.jpg',
#     'medium': '//thumbs.vivino.com/region_backgrounds/9lP_DxrNQnuADJ7Hv4SYuA_600x356.jpg'}}}}

# %%
[i['vintage']['wine']['style']['id'] for i in los ]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-16-ed19b479f5b8> in <module>
# ----> 1 [i['vintage']['wine']['style']['id'] for i in los ]
#
# <ipython-input-16-ed19b479f5b8> in <listcomp>(.0)
# ----> 1 [i['vintage']['wine']['style']['id'] for i in los ]
#
# TypeError: 'NoneType' object is not subscriptable

# %%
los[0]['vintage']['wine']['style']['id']
# Out:
# 190

# %%
sample
# Out:
# {'vintage': {'id': 1831130,
#   'seo_name': 'chateau-pedesclaux-pauillac-grand-cru-classe-2010',
#   'name': 'Château Pedesclaux Pauillac (Grand Cru Classé) 2010',
#   'statistics': {'status': 'Normal',
#    'ratings_count': 1375,
#    'ratings_average': 4.1,
#    'labels_count': 11458,
#    'reviews_count': 452},
#   'organic_certification_id': None,
#   'certified_biodynamic': None,
#   'image': {'location': '//images.vivino.com/thumbs/kNlCNCLhT56LuQuH7ihvVw_pl_480x640.png',
#    'variations': {'bottle_large': '//images.vivino.com/thumbs/kNlCNCLhT56LuQuH7ihvVw_pb_x960.png',
#     'bottle_medium': '//images.vivino.com/thumbs/kNlCNCLhT56LuQuH7ihvVw_pb_x600.png',
#     'bottle_medium_square': '//images.vivino.com/thumbs/kNlCNCLhT56LuQuH7ihvVw_pb_600x600.png',
#     'bottle_small': '//images.vivino.com/thumbs/kNlCNCLhT56LuQuH7ihvVw_pb_x300.png',
#     'bottle_small_square': '//images.vivino.com/thumbs/kNlCNCLhT56LuQuH7ihvVw_pb_300x300.png',
#     'label': '//images.vivino.com/thumbs/kNlCNCLhT56LuQuH7ihvVw_pl_480x640.png',
#     'label_large': '//images.vivino.com/thumbs/kNlCNCLhT56LuQuH7ihvVw_pl_375x500.png',
#     'label_medium': '//images.vivino.com/thumbs/kNlCNCLhT56LuQuH7ihvVw_pl_150x200.png',
#     'label_medium_square': '//images.vivino.com/thumbs/kNlCNCLhT56LuQuH7ihvVw_pl_150x150.png',
#     'label_small_square': '//images.vivino.com/thumbs/kNlCNCLhT56LuQuH7ihvVw_pl_80x80.png',
#     'large': '//images.vivino.com/thumbs/kNlCNCLhT56LuQuH7ihvVw_pl_375x500.png',
#     'medium': '//images.vivino.com/thumbs/kNlCNCLhT56LuQuH7ihvVw_pl_150x200.png',
#     'medium_square': '//images.vivino.com/thumbs/kNlCNCLhT56LuQuH7ihvVw_pl_150x150.png',
#     'small_square': '//images.vivino.com/thumbs/kNlCNCLhT56LuQuH7ihvVw_pl_80x80.png'}},
#   'wine': {'id': 48994,
#    'name': 'Pauillac (Grand Cru Classé)',
#    'seo_name': 'pauillac-grand-cru-classe',
#    'type_id': 1,
#    'vintage_type': 0,
#    'is_natural': False,
#    'region': {'id': 393,
#     'name': 'Pauillac',
#     'name_en': '',
#     'seo_name': 'pauillac',
#     'country': {'code': 'fr',
#      'name': 'France',
#      'native_name': 'France',
#      'seo_name': 'france',
#      'currency': {'code': 'EUR',
#       'name': 'Euros',
#       'prefix': '€',
#       'suffix': None},
#      'regions_count': 1280,
#      'users_count': 3790550,
#      'wines_count': 481923,
#      'wineries_count': 64952,
#      'most_used_grapes': [{'id': 14,
#        'name': 'Pinot Noir',
#        'seo_name': 'pinot-noir',
#        'has_detailed_info': True,
#        'wines_count': 462117},
#       {'id': 10,
#        'name': 'Merlot',
#        'seo_name': 'merlot',
#        'has_detailed_info': True,
#        'wines_count': 461197},
#       {'id': 5,
#        'name': 'Chardonnay',
#        'seo_name': 'chardonnay',
#        'has_detailed_info': True,
#        'wines_count': 487962}]},
#     'background_image': {'location': '//images.vivino.com/regions/backgrounds/-wJ76BSdS0G-h8eEF-Ra7g.jpg',
#      'variations': {'large': '//thumbs.vivino.com/region_backgrounds/-wJ76BSdS0G-h8eEF-Ra7g_1280x760.jpg',
#       'medium': '//thumbs.vivino.com/region_backgrounds/-wJ76BSdS0G-h8eEF-Ra7g_600x356.jpg'}},
#     'class': {'typecast_map': {'background_image': {}, 'class': {}}}},
#    'review_status': 2,
#    'winery': {'id': 2426,
#     'name': 'Château Pedesclaux',
#     'seo_name': 'chateau-pedesclaux',
#     'status': 3,
#     'review_status': 'Completed',
#     'statistics': {'ratings_count': 12368,
#      'ratings_average': 4,
#      'labels_count': 117356,
#      'wines_count': 6},
#     'region': {'id': 393,
#      'name': 'Pauillac',
#      'name_en': '',
#      'seo_name': 'pauillac',
#      'country': {'code': 'fr',
#       'name': 'France',
#       'native_name': 'France',
#       'seo_name': 'france',
#       'currency': {'code': 'EUR',
#        'name': 'Euros',
#        'prefix': '€',
#        'suffix': None},
#       'regions_count': 1280,
#       'users_count': 3790550,
#       'wines_count': 481923,
#       'wineries_count': 64952,
#       'most_used_grapes': [{'id': 14,
#         'name': 'Pinot Noir',
#         'seo_name': 'pinot-noir',
#         'has_detailed_info': True,
#         'wines_count': 462117},
#        {'id': 10,
#         'name': 'Merlot',
#         'seo_name': 'merlot',
#         'has_detailed_info': True,
#         'wines_count': 461197},
#        {'id': 5,
#         'name': 'Chardonnay',
#         'seo_name': 'chardonnay',
#         'has_detailed_info': True,
#         'wines_count': 487962}]},
#      'background_image': {'location': '//images.vivino.com/regions/backgrounds/-wJ76BSdS0G-h8eEF-Ra7g.jpg',
#       'variations': {'large': '//thumbs.vivino.com/region_backgrounds/-wJ76BSdS0G-h8eEF-Ra7g_1280x760.jpg',
#        'medium': '//thumbs.vivino.com/region_backgrounds/-wJ76BSdS0G-h8eEF-Ra7g_600x356.jpg'}},
#      'class': {'typecast_map': {'background_image': {}, 'class': {}}}},
#     'business_name': 'Château Pedesclaux',
#     'description': '',
#     'phone': '33 05 57 73 64 64',
#     'email': 'Contact@chateau-pedesclaux.com',
#     'facebook': '',
#     'instagram': '@chateaupedesclaux/',
#     'is_claimed': True,
#     'twitter': '@Ch_Pedesclaux',
#     'website': 'http://www.chateau-pedesclaux.com',
#     'winemaker': 'Vincent Bache-Gabrielsen',
#     'wine_maker': {'id': 3119, 'name': 'Vincent Bache-Gabrielsen'},
#     'address': {'title': None,
#      'name': None,
#      'street': 'Padarnac',
#      'street2': None,
#      'neighborhood': None,
#      'city': 'Pauillac',
#      'zip': '33250',
#      'state': None,
#      'country': {'code': 'fr',
#       'name': 'France',
#       'native_name': 'France',
#       'seo_name': 'france',
#       'currency': {'code': 'EUR',
#        'name': 'Euros',
#        'prefix': '€',
#        'suffix': None},
#       'regions_count': 1280,
#       'users_count': 3790550,
#       'wines_count': 481923,
#       'wineries_count': 64952,
#       'most_used_grapes': [{'id': 14,
#         'name': 'Pinot Noir',
#         'seo_name': 'pinot-noir',
#         'has_detailed_info': True,
#         'wines_count': 462117},
#        {'id': 10,
#         'name': 'Merlot',
#         'seo_name': 'merlot',
#         'has_detailed_info': True,
#         'wines_count': 461197},
#        {'id': 5,
#         'name': 'Chardonnay',
#         'seo_name': 'chardonnay',
#         'has_detailed_info': True,
#         'wines_count': 487962}]},
#      'company': None,
#      'phone': None,
#      'external_id': None,
#      'residential': None,
#      'vat_number': None,
#      'vat_code': None,
#      'addition': None},
#     'image': {'location': '//images.vivino.com/wineries/2426/logos/e4reesYiQNaLLwZH8UMNng.jpeg',
#      'variations': {'large': '//images.vivino.com/wineries/2426/logos/e4reesYiQNaLLwZH8UMNng_500x500.jpeg',
#       'medium': '//images.vivino.com/wineries/2426/logos/e4reesYiQNaLLwZH8UMNng_200x200.jpeg',
#       'small_square': '//images.vivino.com/wineries/2426/logos/e4reesYiQNaLLwZH8UMNng_80x80.jpeg'}},
#     'background_image': {'location': '//images.vivino.com/wineries/backgrounds/OEI2p1fiRgilkRqOpU6l6g.jpeg',
#      'variations': {'large': '//thumbs.vivino.com/winery_backgrounds/OEI2p1fiRgilkRqOpU6l6g_2560x1520.jpeg',
#       'medium': '//thumbs.vivino.com/winery_backgrounds/OEI2p1fiRgilkRqOpU6l6g_1280x760.jpeg',
#       'small': '//thumbs.vivino.com/winery_backgrounds/OEI2p1fiRgilkRqOpU6l6g_600x356.jpeg'}},
#     'background_video': 'http://images.vivino.com/misc/winery_videos/Cha%CC%82teau-Pe%CC%81desclaux-2426.mp4',
#     'location': {'latitude': 45.213856, 'longitude': -0.760426},
#     'winery_group': None,
#     'first_wines': [{'id': 48994,
#       'name': 'Pauillac (Grand Cru Classé)',
#       'seo_name': 'pauillac-grand-cru-classe',
#       'type_id': 1,
#       'vintage_type': 0,
#       'is_natural': False,
#       'region': None,
#       'review_status': 0}]},
#    'statistics': {'status': 'Normal',
#     'ratings_count': 8671,
#     'ratings_average': 4,
#     'labels_count': 81763,
#     'vintages_count': 84},
#    'rank': {'country': {'description': 'Classement en/au France',
#      'total': 281937,
#      'rank': 5267},
#     'region': {'description': 'Classement au sein de la région vinicole',
#      'total': 202,
#      'rank': 31},
#     'winery': {'description': 'Classement au sein du domaine',
#      'total': 6,
#      'rank': 1},
#     'wine_type': {'description': 'Rank within all Vin rouge',
#      'total': 589828,
#      'rank': 15399},
#     'global': {'description': 'Classement mondial',
#      'total': 1135214,
#      'rank': 21925}},
#    'hidden': False,
#    'vintages': [{'id': 1539612,
#      'seo_name': 'chateau-pedesclaux-pauillac-grand-cru-classe-uv',
#      'name': 'Château Pedesclaux Pauillac (Grand Cru Classé)',
#      'statistics': {'status': 'Normal',
#       'ratings_count': 8671,
#       'ratings_average': 4,
#       'labels_count': 155,
#       'reviews_count': 25},
#      'year': 'U.V.',
#      'grapes': None,
#      'has_valid_ratings': True},
#     {'id': 159376881,
#      'seo_name': 'chateau-pedesclaux-pauillac-grand-cru-classe-2019',
#      'name': 'Château Pedesclaux Pauillac (Grand Cru Classé) 2019',
#      'statistics': {'status': 'BelowThreshold',
#       'ratings_count': 7,
#       'ratings_average': 0,
#       'labels_count': 32,
#       'reviews_count': 6},
#      'year': 2019,
#      'grapes': None,
#      'has_valid_ratings': False},
#     {'id': 156373921,
#      'seo_name': 'chateau-pedesclaux-pauillac-grand-cru-classe-2018',
#      'name': 'Château Pedesclaux Pauillac (Grand Cru Classé) 2018',
#      'statistics': {'status': 'BelowThreshold',
#       'ratings_count': 8,
#       'ratings_average': 0,
#       'labels_count': 39,
#       'reviews_count': 5},
#      'year': 2018,
#      'grapes': None,
#      'has_valid_ratings': False},
#     {'id': 151172015,
#      'seo_name': 'chateau-pedesclaux-pauillac-grand-cru-classe-2017',
#      'name': 'Château Pedesclaux Pauillac (Grand Cru Classé) 2017',
#      'statistics': {'status': 'Normal',
#       'ratings_count': 55,
#       'ratings_average': 3.8,
#       'labels_count': 1334,
#       'reviews_count': 21},
#      'year': 2017,
#      'grapes': None,
#      'has_valid_ratings': True},
#     {'id': 138810534,
#      'seo_name': 'chateau-pedesclaux-pauillac-grand-cru-classe-2016',
#      'name': 'Château Pedesclaux Pauillac (Grand Cru Classé) 2016',
#      'statistics': {'status': 'Normal',
#       'ratings_count': 273,
#       'ratings_average': 4.1,
#       'labels_count': 4220,
#       'reviews_count': 124},
#      'year': 2016,
#      'grapes': None,
#      'has_valid_ratings': True},
#     {'id': 23889761,
#      'seo_name': 'chateau-pedesclaux-pauillac-grand-cru-classe-2015',
#      'name': 'Château Pedesclaux Pauillac (Grand Cru Classé) 2015',
#      'statistics': {'status': 'Normal',
#       'ratings_count': 521,
#       'ratings_average': 4.1,
#       'labels_count': 5959,
#       'reviews_count': 200},
#      'year': 2015,
#      'grapes': None,
#      'has_valid_ratings': True},
#     {'id': 4115141,
#      'seo_name': 'chateau-pedesclaux-pauillac-grand-cru-classe-2014',
#      'name': 'Château Pedesclaux Pauillac (Grand Cru Classé) 2014',
#      'statistics': {'status': 'Normal',
#       'ratings_count': 597,
#       'ratings_average': 4,
#       'labels_count': 5638,
#       'reviews_count': 217},
#      'year': 2014,
#      'grapes': None,
#      'has_valid_ratings': True},
#     {'id': 4223414,
#      'seo_name': 'chateau-pedesclaux-pauillac-grand-cru-classe-2013',
#      'name': 'Château Pedesclaux Pauillac (Grand Cru Classé) 2013',
#      'statistics': {'status': 'Normal',
#       'ratings_count': 431,
#       'ratings_average': 4,
#       'labels_count': 6035,
#       'reviews_count': 145},
#      'year': 2013,
#      'grapes': None,
#      'has_valid_ratings': True},
#     {'id': 4223416,
#      'seo_name': 'chateau-pedesclaux-pauillac-grand-cru-classe-2012',
#      'name': 'Château Pedesclaux Pauillac (Grand Cru Classé) 2012',
#      'statistics': {'status': 'Normal',
#       'ratings_count': 935,
#       'ratings_average': 3.9,
#       'labels_count': 9642,
#       'reviews_count': 286},
#      'year': 2012,
#      'grapes': None,
#      'has_valid_ratings': True},
#     {'id': 2319988,
#      'seo_name': 'chateau-pedesclaux-pauillac-grand-cru-classe-2011',
#      'name': 'Château Pedesclaux Pauillac (Grand Cru Classé) 2011',
#      'statistics': {'status': 'Normal',
#       'ratings_count': 880,
#       'ratings_average': 3.9,
#       'labels_count': 8689,
#       'reviews_count': 277},
#      'year': 2011,
#      'grapes': None,
#      'has_valid_ratings': True},
#     {'id': 1831130,
#      'seo_name': 'chateau-pedesclaux-pauillac-grand-cru-classe-2010',
#      'name': 'Château Pedesclaux Pauillac (Grand Cru Classé) 2010',
#      'statistics': {'status': 'Normal',
#       'ratings_count': 1375,
#       'ratings_average': 4.1,
#       'labels_count': 11458,
#       'reviews_count': 452},
#      'year': 2010,
#      'grapes': None,
#      'has_valid_ratings': True},
#     {'id': 1311854,
#      'seo_name': 'chateau-pedesclaux-pauillac-grand-cru-classe-2009',
#      'name': 'Château Pedesclaux Pauillac (Grand Cru Classé) 2009',
#      'statistics': {'status': 'Normal',
#       'ratings_count': 741,
#       'ratings_average': 4.2,
#       'labels_count': 4861,
#       'reviews_count': 238},
#      'year': 2009,
#      'grapes': None,
#      'has_valid_ratings': True},
#     {'id': 1243165,
#      'seo_name': 'chateau-pedesclaux-pauillac-grand-cru-classe-2008',
#      'name': 'Château Pedesclaux Pauillac (Grand Cru Classé) 2008',
#      'statistics': {'status': 'Normal',
#       'ratings_count': 478,
#       'ratings_average': 4,
#       'labels_count': 3452,
#       'reviews_count': 141},
#      'year': 2008,
#      'grapes': None,
#      'has_valid_ratings': True},
#     {'id': 1237615,
#      'seo_name': 'chateau-pedesclaux-pauillac-grand-cru-classe-2007',
#      'name': 'Château Pedesclaux Pauillac (Grand Cru Classé) 2007',
#      'statistics': {'status': 'Normal',
#       'ratings_count': 292,
#       'ratings_average': 4,
#       'labels_count': 2255,
#       'reviews_count': 77},
#      'year': 2007,
#      'grapes': None,
#      'has_valid_ratings': True},
#     {'id': 1214164,
#      'seo_name': 'chateau-pedesclaux-pauillac-grand-cru-classe-2006',
#      'name': 'Château Pedesclaux Pauillac (Grand Cru Classé) 2006',
#      'statistics': {'status': 'Normal',
#       'ratings_count': 516,
#       'ratings_average': 4,
#       'labels_count': 3768,
#       'reviews_count': 151},
#      'year': 2006,
#      'grapes': None,
#      'has_valid_ratings': True},
#     {'id': 53004,
#      'seo_name': 'chateau-pedesclaux-pauillac-grand-cru-classe-2005',
#      'name': 'Château Pedesclaux Pauillac (Grand Cru Classé) 2005',
#      'statistics': {'status': 'Normal',
#       'ratings_count': 331,
#       'ratings_average': 4,
#       'labels_count': 2809,
#       'reviews_count': 114},
#      'year': 2005,
#      'grapes': None,
#      'has_valid_ratings': True},
#     {'id': 1211585,
#      'seo_name': 'chateau-pedesclaux-pauillac-grand-cru-classe-2004',
#      'name': 'Château Pedesclaux Pauillac (Grand Cru Classé) 2004',
#      'statistics': {'status': 'Normal',
#       'ratings_count': 248,
#       'ratings_average': 4,
#       'labels_count': 1905,
#       'reviews_count': 72},
#      'year': 2004,
#      'grapes': None,
#      'has_valid_ratings': True},
#     {'id': 1207559,
#      'seo_name': 'chateau-pedesclaux-pauillac-grand-cru-classe-2003',
#      'name': 'Château Pedesclaux Pauillac (Grand Cru Classé) 2003',
#      'statistics': {'status': 'Normal',
#       'ratings_count': 147,
#       'ratings_average': 4.1,
#       'labels_count': 1269,
#       'reviews_count': 39},
#      'year': 2003,
#      'grapes': None,
#      'has_valid_ratings': True},
#     {'id': 1894721,
#      'seo_name': 'chateau-pedesclaux-pauillac-grand-cru-classe-2002',
#      'name': 'Château Pedesclaux Pauillac (Grand Cru Classé) 2002',
#      'statistics': {'status': 'Normal',
#       'ratings_count': 39,
#       'ratings_average': 3.9,
#       'labels_count': 582,
#       'reviews_count': 15},
#      'year': 2002,
#      'grapes': None,
#      'has_valid_ratings': True},
#     {'id': 1487763,
#      'seo_name': 'chateau-pedesclaux-pauillac-grand-cru-classe-2001',
#      'name': 'Château Pedesclaux Pauillac (Grand Cru Classé) 2001',
#      'statistics': {'status': 'Normal',
#       'ratings_count': 53,
#       'ratings_average': 3.7,
#       'labels_count': 528,
#       'reviews_count': 16},
#      'year': 2001,
#      'grapes': None,
#      'has_valid_ratings': True},
#     {'id': 1345837,
#      'seo_name': 'chateau-pedesclaux-pauillac-grand-cru-classe-2000',
#      'name': 'Château Pedesclaux Pauillac (Grand Cru Classé) 2000',
#      'statistics': {'status': 'Normal',
#       'ratings_count': 91,
#       'ratings_average': 4.2,
#       'labels_count': 895,
#       'reviews_count': 29},
#      'year': 2000,
#      'grapes': None,
#      'has_valid_ratings': True},
#     {'id': 1291974,
#      'seo_name': 'chateau-pedesclaux-pauillac-grand-cru-classe-1999',
#      'name': 'Château Pedesclaux Pauillac (Grand Cru Classé) 1999',
#      'statistics': {'status': 'Normal',
#       'ratings_count': 58,
#       'ratings_average': 3.9,
#       'labels_count': 640,
#       'reviews_count': 22},
#      'year': 1999,
#      'grapes': None,
#      'has_valid_ratings': True},
#     {'id': 1161470,
#      'seo_name': 'chateau-pedesclaux-pauillac-grand-cru-classe-1998',
#      'name': 'Château Pedesclaux Pauillac (Grand Cru Classé) 1998',
#      'statistics': {'status': 'Normal',
#       'ratings_count': 71,
#       'ratings_average': 3.8,
#       'labels_count': 555,
#       'reviews_count': 21},
#      'year': 1998,
#      'grapes': None,
#      'has_valid_ratings': True},
#     {'id': 1190884,
#      'seo_name': 'chateau-pedesclaux-pauillac-grand-cru-classe-1997',
#      'name': 'Château Pedesclaux Pauillac (Grand Cru Classé) 1997',
#      'statistics': {'status': 'Normal',
#       'ratings_count': 43,
#       'ratings_average': 3.9,
#       'labels_count': 543,
#       'reviews_count': 9},
#      'year': 1997,
#      'grapes': None,
#      'has_valid_ratings': True},
#     {'id': 1906053,
#      'seo_name': 'chateau-pedesclaux-pauillac-grand-cru-classe-1996',
#      'name': 'Château Pedesclaux Pauillac (Grand Cru Classé) 1996',
#      'statistics': {'status': 'Normal',
#       'ratings_count': 51,
#       'ratings_average': 3.8,
#       'labels_count': 408,
#       'reviews_count': 21},
#      'year': 1996,
#      'grapes': None,
#      'has_valid_ratings': True},
#     {'id': 2541080,
#      'seo_name': 'chateau-pedesclaux-pauillac-grand-cru-classe-1995',
#      'name': 'Château Pedesclaux Pauillac (Grand Cru Classé) 1995',
#      'statistics': {'status': 'Normal',
#       'ratings_count': 34,
#       'ratings_average': 4.1,
#       'labels_count': 321,
#       'reviews_count': 18},
#      'year': 1995,
#      'grapes': None,
#      'has_valid_ratings': True},
#     {'id': 1275133,
#      'seo_name': 'chateau-pedesclaux-pauillac-grand-cru-classe-1994',
#      'name': 'Château Pedesclaux Pauillac (Grand Cru Classé) 1994',
#      'statistics': {'status': 'Normal',
#       'ratings_count': 26,
#       'ratings_average': 3.8,
#       'labels_count': 325,
#       'reviews_count': 9},
#      'year': 1994,
#      'grapes': None,
#      'has_valid_ratings': True},
#     {'id': 1282342,
#      'seo_name': 'chateau-pedesclaux-pauillac-grand-cru-classe-1993',
#      'name': 'Château Pedesclaux Pauillac (Grand Cru Classé) 1993',
#      'statistics': {'status': 'Normal',
#       'ratings_count': 18,
#       'ratings_average': 4.2,
#       'labels_count': 250,
#       'reviews_count': 5},
#      'year': 1993,
#      'grapes': None,
#      'has_valid_ratings': True},
#     {'id': 1452493,
#      'seo_name': 'chateau-pedesclaux-pauillac-grand-cru-classe-1992',
#      'name': 'Château Pedesclaux Pauillac (Grand Cru Classé) 1992',
#      'statistics': {'status': 'BelowThreshold',
#       'ratings_count': 8,
#       'ratings_average': 0,
#       'labels_count': 120,
#       'reviews_count': 2},
#      'year': 1992,
#      'grapes': None,
#      'has_valid_ratings': False},
#     {'id': 3788308,
#      'seo_name': 'chateau-pedesclaux-pauillac-grand-cru-classe-1991',
#      'name': 'Château Pedesclaux Pauillac (Grand Cru Classé) 1991',
#      'statistics': {'status': 'BelowThreshold',
#       'ratings_count': 4,
#       'ratings_average': 0,
#       'labels_count': 56,
#       'reviews_count': 2},
#      'year': 1991,
#      'grapes': None,
#      'has_valid_ratings': False},
#     {'id': 3411585,
#      'seo_name': 'chateau-pedesclaux-pauillac-grand-cru-classe-1990',
#      'name': 'Château Pedesclaux Pauillac (Grand Cru Classé) 1990',
#      'statistics': {'status': 'Normal',
#       'ratings_count': 29,
#       'ratings_average': 3.6,
#       'labels_count': 235,
#       'reviews_count': 13},
#      'year': 1990,
#      'grapes': None,
#      'has_valid_ratings': True},
#     {'id': 2705653,
#      'seo_name': 'chateau-pedesclaux-pauillac-grand-cru-classe-1989',
#      'name': 'Château Pedesclaux Pauillac (Grand Cru Classé) 1989',
#      'statistics': {'status': 'Normal',
#       'ratings_count': 21,
#       'ratings_average': 4.2,
#       'labels_count': 265,
#       'reviews_count': 8},
#      'year': 1989,
#      'grapes': None,
#      'has_valid_ratings': True},
#     {'id': 2108309,
#      'seo_name': 'chateau-pedesclaux-pauillac-grand-cru-classe-1988',
#      'name': 'Château Pedesclaux Pauillac (Grand Cru Classé) 1988',
#      'statistics': {'status': 'Normal',
#       'ratings_count': 22,
#       'ratings_average': 4,
#       'labels_count': 177,
#       'reviews_count': 8},
#      'year': 1988,
#      'grapes': None,
#      'has_valid_ratings': True},
#     {'id': 3280867,
#      'seo_name': 'chateau-pedesclaux-pauillac-grand-cru-classe-1987',
#      'name': 'Château Pedesclaux Pauillac (Grand Cru Classé) 1987',
#      'statistics': {'status': 'BelowThreshold',
#       'ratings_count': 3,
#       'ratings_average': 0,
#       'labels_count': 46,
#       'reviews_count': 0},
#      'year': 1987,
#      'grapes': None,
#      'has_valid_ratings': False},
#     {'id': 3604152,
#      'seo_name': 'chateau-pedesclaux-pauillac-grand-cru-classe-1986',
#      'name': 'Château Pedesclaux Pauillac (Grand Cru Classé) 1986',
#      'statistics': {'status': 'Normal',
#       'ratings_count': 23,
#       'ratings_average': 3.9,
#       'labels_count': 285,
#       'reviews_count': 11},
#      'year': 1986,
#      'grapes': None,
#      'has_valid_ratings': True},
#     {'id': 1431791,
#      'seo_name': 'chateau-pedesclaux-pauillac-grand-cru-classe-1985',
#      'name': 'Château Pedesclaux Pauillac (Grand Cru Classé) 1985',
#      'statistics': {'status': 'Normal',
#       'ratings_count': 11,
#       'ratings_average': 3.9,
#       'labels_count': 114,
#       'reviews_count': 4},
#      'year': 1985,
#      'grapes': None,
#      'has_valid_ratings': True},
#     {'id': 3055457,
#      'seo_name': 'chateau-pedesclaux-pauillac-grand-cru-classe-1984',
#      'name': 'Château Pedesclaux Pauillac (Grand Cru Classé) 1984',
#      'statistics': {'status': 'BelowThreshold',
#       'ratings_count': 2,
#       'ratings_average': 0,
#       'labels_count': 35,
#       'reviews_count': 0},
#      'year': 1984,
#      'grapes': None,
#      'has_valid_ratings': False},
#     {'id': 3410857,
#      'seo_name': 'chateau-pedesclaux-pauillac-grand-cru-classe-1983',
#      'name': 'Château Pedesclaux Pauillac (Grand Cru Classé) 1983',
#      'statistics': {'status': 'Normal',
#       'ratings_count': 14,
#       'ratings_average': 3.5,
#       'labels_count': 68,
#       'reviews_count': 4},
#      'year': 1983,
#      'grapes': None,
#      'has_valid_ratings': True},
#     {'id': 2541072,
#      'seo_name': 'chateau-pedesclaux-pauillac-grand-cru-classe-1982',
#      'name': 'Château Pedesclaux Pauillac (Grand Cru Classé) 1982',
#      'statistics': {'status': 'Normal',
#       'ratings_count': 17,
#       'ratings_average': 4.4,
#       'labels_count': 177,
#       'reviews_count': 4},
#      'year': 1982,
#      'grapes': None,
#      'has_valid_ratings': True},
#     {'id': 4044068,
#      'seo_name': 'chateau-pedesclaux-pauillac-grand-cru-classe-1981',
#      'name': 'Château Pedesclaux Pauillac (Grand Cru Classé) 1981',
#      'statistics': {'status': 'BelowThreshold',
#       'ratings_count': 6,
#       'ratings_average': 0,
#       'labels_count': 122,
#       'reviews_count': 4},
#      'year': 1981,
#      'grapes': None,
#      'has_valid_ratings': False},
#     {'id': 3281491,
#      'seo_name': 'chateau-pedesclaux-pauillac-grand-cru-classe-1980',
#      'name': 'Château Pedesclaux Pauillac (Grand Cru Classé) 1980',
#      'statistics': {'status': 'BelowThreshold',
#       'ratings_count': 1,
#       'ratings_average': 0,
#       'labels_count': 6,
#       'reviews_count': 0},
#      'year': 1980,
#      'grapes': None,
#      'has_valid_ratings': False},
#     {'id': 4291930,
#      'seo_name': 'chateau-pedesclaux-pauillac-grand-cru-classe-1979',
#      'name': 'Château Pedesclaux Pauillac (Grand Cru Classé) 1979',
#      'statistics': {'status': 'BelowThreshold',
#       'ratings_count': 4,
#       'ratings_average': 0,
#       'labels_count': 23,
#       'reviews_count': 0},
#      'year': 1979,
#      'grapes': None,
#      'has_valid_ratings': False},
#     {'id': 5112764,
#      'seo_name': 'chateau-pedesclaux-pauillac-grand-cru-classe-1978',
#      'name': 'Château Pedesclaux Pauillac (Grand Cru Classé) 1978',
#      'statistics': {'status': 'Normal',
#       'ratings_count': 11,
#       'ratings_average': 3,
#       'labels_count': 152,
#       'reviews_count': 4},
#      'year': 1978,
#      'grapes': None,
#      'has_valid_ratings': True},
#     {'id': 92258635,
#      'seo_name': 'chateau-pedesclaux-pauillac-grand-cru-classe-1977',
#      'name': 'Château Pedesclaux Pauillac (Grand Cru Classé) 1977',
#      'statistics': {'status': 'BelowThreshold',
#       'ratings_count': 1,
#       'ratings_average': 0,
#       'labels_count': 17,
#       'reviews_count': 0},
#      'year': 1977,
#      'grapes': None,
#      'has_valid_ratings': False},
#     {'id': 2943604,
#      'seo_name': 'chateau-pedesclaux-pauillac-grand-cru-classe-1976',
#      'name': 'Château Pedesclaux Pauillac (Grand Cru Classé) 1976',
#      'statistics': {'status': 'BelowThreshold',
#       'ratings_count': 9,
#       'ratings_average': 0,
#       'labels_count': 175,
#       'reviews_count': 4},
#      'year': 1976,
#      'grapes': None,
#      'has_valid_ratings': False},
#     {'id': 1378744,
#      'seo_name': 'chateau-pedesclaux-pauillac-grand-cru-classe-1975',
#      'name': 'Château Pedesclaux Pauillac (Grand Cru Classé) 1975',
#      'statistics': {'status': 'Normal',
#       'ratings_count': 17,
#       'ratings_average': 3.6,
#       'labels_count': 179,
#       'reviews_count': 5},
#      'year': 1975,
#      'grapes': None,
#      'has_valid_ratings': True},
#     {'id': 4081449,
#      'seo_name': 'chateau-pedesclaux-pauillac-grand-cru-classe-1973',
#      'name': 'Château Pedesclaux Pauillac (Grand Cru Classé) 1973',
#      'statistics': {'status': 'BelowThreshold',
#       'ratings_count': 1,
#       'ratings_average': 0,
#       'labels_count': 18,
#       'reviews_count': 0},
#      'year': 1973,
#      'grapes': None,
#      'has_valid_ratings': False},
#     {'id': 1229189,
#      'seo_name': 'chateau-pedesclaux-pauillac-grand-cru-classe-1971',
#      'name': 'Château Pedesclaux Pauillac (Grand Cru Classé) 1971',
#      'statistics': {'status': 'BelowThreshold',
#       'ratings_count': 5,
#       'ratings_average': 0,
#       'labels_count': 75,
#       'reviews_count': 1},
#      'year': 1971,
#      'grapes': None,
#      'has_valid_ratings': False},
#     {'id': 3706238,
#      'seo_name': 'chateau-pedesclaux-pauillac-grand-cru-classe-1970',
#      'name': 'Château Pedesclaux Pauillac (Grand Cru Classé) 1970',
#      'statistics': {'status': 'Normal',
#       'ratings_count': 12,
#       'ratings_average': 3.8,
#       'labels_count': 110,
#       'reviews_count': 6},
#      'year': 1970,
#      'grapes': None,
#      'has_valid_ratings': True},
#     {'id': 2952885,
#      'seo_name': 'chateau-pedesclaux-pauillac-grand-cru-classe-1967',
#      'name': 'Château Pedesclaux Pauillac (Grand Cru Classé) 1967',
#      'statistics': {'status': 'BelowThreshold',
#       'ratings_count': 9,
#       'ratings_average': 0,
#       'labels_count': 49,
#       'reviews_count': 3},
#      'year': 1967,
#      'grapes': None,
#      'has_valid_ratings': False},
#     {'id': 11382801,
#      'seo_name': 'chateau-pedesclaux-pauillac-grand-cru-classe-1966',
#      'name': 'Château Pedesclaux Pauillac (Grand Cru Classé) 1966',
#      'statistics': {'status': 'BelowThreshold',
#       'ratings_count': 3,
#       'ratings_average': 0,
#       'labels_count': 24,
#       'reviews_count': 0},
#      'year': 1966,
#      'grapes': None,
#      'has_valid_ratings': False},
#     {'id': 3822483,
#      'seo_name': 'chateau-pedesclaux-pauillac-grand-cru-classe-1964',
#      'name': 'Château Pedesclaux Pauillac (Grand Cru Classé) 1964',
#      'statistics': {'status': 'BelowThreshold',
#       'ratings_count': 4,
#       'ratings_average': 0,
#       'labels_count': 18,
#       'reviews_count': 1},
#      'year': 1964,
#      'grapes': None,
#      'has_valid_ratings': False},
#     {'id': 5055152,
#      'seo_name': 'chateau-pedesclaux-pauillac-grand-cru-classe-1962',
#      'name': 'Château Pedesclaux Pauillac (Grand Cru Classé) 1962',
#      'statistics': {'status': 'BelowThreshold',
#       'ratings_count': 2,
#       'ratings_average': 0,
#       'labels_count': 5,
#       'reviews_count': 1},
#      'year': 1962,
#      'grapes': None,
#      'has_valid_ratings': False},
#     {'id': 1566897,
#      'seo_name': 'chateau-pedesclaux-pauillac-grand-cru-classe-1961',
#      'name': 'Château Pedesclaux Pauillac (Grand Cru Classé) 1961',
#      'statistics': {'status': 'BelowThreshold',
#       'ratings_count': 2,
#       'ratings_average': 0,
#       'labels_count': 8,
#       'reviews_count': 1},
#      'year': 1961,
#      'grapes': None,
#      'has_valid_ratings': False},
#     {'id': 1244928,
#      'seo_name': 'chateau-pedesclaux-pauillac-grand-cru-classe-1959',
#      'name': 'Château Pedesclaux Pauillac (Grand Cru Classé) 1959',
#      'statistics': {'status': 'BelowThreshold',
#       'ratings_count': 1,
#       'ratings_average': 0,
#       'labels_count': 11,
#       'reviews_count': 0},
#      'year': 1959,
#      'grapes': None,
#      'has_valid_ratings': False},
#     {'id': 39314508,
#      'seo_name': 'chateau-pedesclaux-pauillac-grand-cru-classe-1947',
#      'name': 'Château Pedesclaux Pauillac (Grand Cru Classé) 1947',
#      'statistics': {'status': 'BelowThreshold',
#       'ratings_count': 1,
#       'ratings_average': 0,
#       'labels_count': 4,
#       'reviews_count': 1},
#      'year': 1947,
#      'grapes': None,
#      'has_valid_ratings': False},
#     {'id': 155196909,
#      'seo_name': 'chateau-pedesclaux-pauillac-grand-cru-classe-1934',
#      'name': 'Château Pedesclaux Pauillac (Grand Cru Classé) 1934',
#      'statistics': {'status': 'BelowThreshold',
#       'ratings_count': 1,
#       'ratings_average': 0,
#       'labels_count': 2,
#       'reviews_count': 0},
#      'year': 1934,
#      'grapes': None,
#      'has_valid_ratings': False}],
#    'description': "This wine's beautiful purple color is very deep, the nose is very aromatic with nice ripe black fruit. It is  round and harmonious on the palate with silky tannins and a long finish.\n",
#    'grapes': [{'id': 2,
#      'name': 'Cabernet Sauvignon',
#      'seo_name': 'cabernet-sauvignon',
#      'has_detailed_info': True,
#      'wines_count': 658524},
#     {'id': 3,
#      'name': 'Cabernet Franc',
#      'seo_name': 'cabernet-franc',
#      'has_detailed_info': True,
#      'wines_count': 219118},
#     {'id': 10,
#      'name': 'Merlot',
#      'seo_name': 'merlot',
#      'has_detailed_info': True,
#      'wines_count': 461197}],
#    'foods': [{'id': 4,
#      'name': 'Bœuf',
#      'background_image': {'location': '//images.vivino.com/backgrounds/foods/4_beef.png',
#       'variations': {'small': '//images.vivino.com/backgrounds/foods/thumbs/4_beef_932x810.png'}},
#      'seo_name': 'beef'},
#     {'id': 8,
#      'name': 'Agneau',
#      'background_image': {'location': '//images.vivino.com/backgrounds/foods/8_lamb.png',
#       'variations': {'small': '//images.vivino.com/backgrounds/foods/thumbs/8_lamb_932x810.png'}},
#      'seo_name': 'lamb'},
#     {'id': 11,
#      'name': 'Gibier (cerf, chevreuil)',
#      'background_image': {'location': '//images.vivino.com/backgrounds/foods/11_venison.png',
#       'variations': {'small': '//images.vivino.com/backgrounds/foods/thumbs/11_venison_932x810.png'}},
#      'seo_name': 'game'},
#     {'id': 20,
#      'name': 'Volaille',
#      'background_image': {'location': '//images.vivino.com/backgrounds/foods/20_chicken.png',
#       'variations': {'small': '//images.vivino.com/backgrounds/foods/thumbs/20_chicken_932x810.png'}},
#      'seo_name': 'poultry'}],
#    'non_vintage': False,
#    'alcohol': 0,
#    'sweetness_id': 5,
#    'vintage_mask_raw': None,
#    'created_at': '2009-07-24T00:16:29Z',
#    'is_first_wine': True,
#    'style': {'id': 264,
#     'seo_name': 'bordeaux-left-bank-pauillac',
#     'regional_name': 'Bordeaux Left Bank',
#     'varietal_name': 'Pauillac',
#     'name': 'Pauillac',
#     'image': None,
#     'background_image': None,
#     'description': "Bordeaux Pauillac wines are rich and concentrated, full-bodied reds with grippy tannins, and characteristic notes of cassis, cedar and cigar box spice.\n\nThe best examples come from blends with a base of high-quality Cabernet Sauvignon and are often considered the quintessential example of a Bordeaux wine.\n\nPauillac, in Bordeaux's Left Bank Médoc region, boasts well-draining gravel soils, which in turn translates to higher quality wines; and those from Pauillac age extremely well.\n\nThree of the five first-growths from the 1855 classification of the Médoc are situated in Pauillac: Lafite, Latour, and Mouton-Rothschild.",
#     'blurb': None,
#     'interesting_facts': ["Though Pauillac boasts some of Bordeaux's most acclaimed estates, the town itself is very small.",
#      "More than half of the 18 classified 'Fifth-Growths' are in Pauillac, including the famous Château Lynch-Bages.",
#      "Château Mouton-Rothschild, which encompases 90 hectares (222 acres) in Pauillac was elevated from a 'Second-Growth' to a 'First-Growth in 1973—the only time in the history of the 1855 Classification that a winery's classified position was re-evaluated."],
#     'body': 4,
#     'body_description': 'Corsé',
#     'acidity': 3,
#     'acidity_description': 'Élevée',
#     'country': {'code': 'fr',
#      'name': 'France',
#      'native_name': 'France',
#      'seo_name': 'france',
#      'currency': {'code': 'EUR',
#       'name': 'Euros',
#       'prefix': '€',
#       'suffix': None},
#      'regions_count': 1280,
#      'users_count': 3790550,
#      'wines_count': 481923,
#      'wineries_count': 64952,
#      'most_used_grapes': [{'id': 14,
#        'name': 'Pinot Noir',
#        'seo_name': 'pinot-noir',
#        'has_detailed_info': True,
#        'wines_count': 462117},
#       {'id': 10,
#        'name': 'Merlot',
#        'seo_name': 'merlot',
#        'has_detailed_info': True,
#        'wines_count': 461197},
#       {'id': 5,
#        'name': 'Chardonnay',
#        'seo_name': 'chardonnay',
#        'has_detailed_info': True,
#        'wines_count': 487962}]},
#     'wine_type_id': 1,
#     'food': [{'id': 4,
#       'name': 'Beef',
#       'background_image': {'location': '//images.vivino.com/backgrounds/foods/4_beef.png',
#        'variations': {'small': '//images.vivino.com/backgrounds/foods/thumbs/4_beef_932x810.png'}},
#       'seo_name': 'beef'},
#      {'id': 8,
#       'name': 'Lamb',
#       'background_image': {'location': '//images.vivino.com/backgrounds/foods/8_lamb.png',
#        'variations': {'small': '//images.vivino.com/backgrounds/foods/thumbs/8_lamb_932x810.png'}},
#       'seo_name': 'lamb'},
#      {'id': 11,
#       'name': 'Game (deer, venison)',
#       'background_image': {'location': '//images.vivino.com/backgrounds/foods/11_venison.png',
#        'variations': {'small': '//images.vivino.com/backgrounds/foods/thumbs/11_venison_932x810.png'}},
#       'seo_name': 'game'},
#      {'id': 20,
#       'name': 'Poultry',
#       'background_image': {'location': '//images.vivino.com/backgrounds/foods/20_chicken.png',
#        'variations': {'small': '//images.vivino.com/backgrounds/foods/thumbs/20_chicken_932x810.png'}},
#       'seo_name': 'poultry'}],
#     'grapes': [{'id': 2,
#       'name': 'Cabernet Sauvignon',
#       'seo_name': 'cabernet-sauvignon',
#       'has_detailed_info': True,
#       'wines_count': 658524},
#      {'id': 3,
#       'name': 'Cabernet Franc',
#       'seo_name': 'cabernet-franc',
#       'has_detailed_info': True,
#       'wines_count': 219118},
#      {'id': 9,
#       'name': 'Malbec',
#       'seo_name': 'malbec',
#       'has_detailed_info': True,
#       'wines_count': 179553},
#      {'id': 10,
#       'name': 'Merlot',
#       'seo_name': 'merlot',
#       'has_detailed_info': True,
#       'wines_count': 461197},
#      {'id': 42,
#       'name': 'Petit Verdot',
#       'seo_name': 'petit-verdot',
#       'has_detailed_info': True,
#       'wines_count': 68232},
#      {'id': 51,
#       'name': 'Carménère',
#       'seo_name': 'carmenere',
#       'has_detailed_info': True,
#       'wines_count': 41738}],
#     'region': {'id': 383,
#      'name': 'Bordeaux',
#      'name_en': '',
#      'seo_name': 'bordeaux',
#      'country': {'code': 'fr',
#       'name': 'France',
#       'native_name': 'France',
#       'seo_name': 'france',
#       'currency': {'code': 'EUR',
#        'name': 'Euros',
#        'prefix': '€',
#        'suffix': None},
#       'regions_count': 1280,
#       'users_count': 3790550,
#       'wines_count': 481923,
#       'wineries_count': 64952,
#       'most_used_grapes': [{'id': 14,
#         'name': 'Pinot Noir',
#         'seo_name': 'pinot-noir',
#         'has_detailed_info': True,
#         'wines_count': 462117},
#        {'id': 10,
#         'name': 'Merlot',
#         'seo_name': 'merlot',
#         'has_detailed_info': True,
#         'wines_count': 461197},
#        {'id': 5,
#         'name': 'Chardonnay',
#         'seo_name': 'chardonnay',
#         'has_detailed_info': True,
#         'wines_count': 487962}]},
#      'background_image': {'location': '//images.vivino.com/regions/backgrounds/sbzA7h1ITnaHABaVqWJ4CA.jpg',
#       'variations': {'large': '//thumbs.vivino.com/region_backgrounds/sbzA7h1ITnaHABaVqWJ4CA_1280x760.jpg',
#        'medium': '//thumbs.vivino.com/region_backgrounds/sbzA7h1ITnaHABaVqWJ4CA_600x356.jpg'}},
#      'class': {'typecast_map': {'background_image': {}, 'class': {}}}}},
#    'has_valid_ratings': True},
#   'description': '',
#   'expert_reviews': None,
#   'wine_critic_reviews': [{'id': 1762754,
#     'wine_critic_id': 1,
#     'score': '(85 - 87)',
#     'score_normalized': 87,
#     'reviewed_at': '2011-05-02T00:00:00Z'},
#    {'id': 1871291,
#     'wine_critic_id': 1,
#     'score': '88',
#     'score_normalized': 88,
#     'reviewed_at': '2017-02-28T00:00:00Z'},
#    {'id': 2501511,
#     'wine_critic_id': 34,
#     'score': '15.5',
#     'score_normalized': 85,
#     'reviewed_at': '2013-03-01T00:00:00Z'},
#    {'id': 2505739,
#     'wine_critic_id': 34,
#     'score': '15.5',
#     'score_normalized': 85,
#     'reviewed_at': '2011-06-01T00:00:00Z'},
#    {'id': 2761153,
#     'wine_critic_id': 15,
#     'score': '90',
#     'score_normalized': 90,
#     'reviewed_at': '2015-10-01T00:00:00Z'}],
#   'awards': [],
#   'ratings_distribution': {'1': 7, '2': 19, '3': 246, '4': 896, '5': 207},
#   'ranking': {'country': {'description': 'Classement en/au France',
#     'total': 2132854,
#     'rank': 27612},
#    'region': {'description': 'Classement au sein de la région vinicole',
#     'total': 4998,
#     'rank': 696},
#    'winery': {'description': 'Classement au sein du domaine',
#     'total': 114,
#     'rank': 3},
#    'global': {'description': 'Classement mondial',
#     'total': 7594213,
#     'rank': 117832}},
#   'top_list_rankings': [{'rank': 15,
#     'previous_rank': 15,
#     'description': None,
#     'top_list': {'id': 629557,
#      'name': 'Meilleurs 25 Bordeaux Pauillac vinsdisponibles actuellement en France',
#      'seo_name': 'top-25-bordeaux-pauillac-wines-france-right-now-france',
#      'country': 'fr',
#      'state': None,
#      'level': 0,
#      'intro_header': None,
#      'description': 'Voici les meilleurs 25 Bordeaux Pauillac vins notés récemment par les utilisateurs de Vivino en France.<br><br>Vous souhaitez voir apparaître vos favoris sur la liste ? Pensez à les noter et consultez la liste chaque semaine.<br>Prochaine mise à jour dans 1 jour',
#      'short_description': 'Voici la liste des meilleurs 25 Bordeaux Pauillac vins notés par les utilisateurs de Vivino, mise à jour chaque semaine.',
#      'updated_at': '2020-08-21T01:03:03.000Z',
#      'image': {'location': '//images.vivino.com/top_lists/toplist_chart_expensive.png',
#       'variations': {'medium': '//images.vivino.com/top_lists/toplist_chart_expensive_468x276.png'}},
#      'icon': None,
#      'author': None}}],
#   'wine_facts': {'alcohol': 13},
#   'winemaker': None,
#   'wine_maker': None,
#   'grape_composition': {'2': 100},
#   'year': 2010,
#   'grapes': [{'id': 2,
#     'name': 'Cabernet Sauvignon',
#     'seo_name': 'cabernet-sauvignon',
#     'has_detailed_info': True,
#     'wines_count': 658524}],
#   'has_valid_ratings': True},
#  'price': {'id': 17010387,
#   'vintage_id': 1831130,
#   'amount': 77,
#   'currency': {'code': 'EUR', 'name': 'Euros', 'prefix': '€', 'suffix': None},
#   'bottle_type_id': 1,
#   'inventory_bottles_count': 576,
#   'url': 'https://club.ovinia.fr/catalogue-vins/?utm_medium=pref-cpc&utm_source=vivino-ppc',
#   'message': 'Prix par bouteille, caisse de 12 bouteilles',
#   'producer_address': None,
#   'importer_address': None,
#   'discounted_from': None,
#   'bottle_type': {'id': 1,
#    'name': 'Bouteille (75cl)',
#    'short_name': 'bouteille',
#    'short_name_plural': 'bouteilles',
#    'volume_ml': 750}},
#  'highlights': [{'vintage_id': 1831130,
#    'highlight_type': 'most_user_rated',
#    'message': 'Populaire parmi les utilisateurs Vivino. Plus de 1300\xa0notes',
#    'icon': 'https://images.vivino.com/highlights/icon/most_user_rated.svg',
#    'metadata': {'price': {'id': 17010387,
#      'type': 'vc',
#      'amount': 77,
#      'currency': {'code': 'EUR',
#       'name': 'Euros',
#       'prefix': '€',
#       'suffix': None},
#      'discounted_from': None},
#     'wine_id': 48994,
#     'toplist': None,
#     'ws_award': None,
#     'critic_review_id': 2761153,
#     'ratings_average': 4.1,
#     'ratings_count': 1375,
#     'vintage_year': '2010',
#     'rank_type': 'global',
#     'ranks': {'country': {'description': 'Classement en/au France',
#       'total': 2132854,
#       'rank': 27612},
#      'region': {'description': 'Classement au sein de la région vinicole',
#       'total': 4998,
#       'rank': 696},
#      'winery': {'description': 'Classement au sein du domaine',
#       'total': 114,
#       'rank': 3},
#      'global': {'description': 'Classement mondial',
#       'total': 7594213,
#       'rank': 117832}},
#     'style': {'id': 264,
#      'seo_name': 'bordeaux-left-bank-pauillac',
#      'regional_name': 'Bordeaux Left Bank',
#      'varietal_name': 'Pauillac',
#      'name': 'Pauillac',
#      'image': None,
#      'background_image': None,
#      'description': "Bordeaux Pauillac wines are rich and concentrated, full-bodied reds with grippy tannins, and characteristic notes of cassis, cedar and cigar box spice.\n\nThe best examples come from blends with a base of high-quality Cabernet Sauvignon and are often considered the quintessential example of a Bordeaux wine.\n\nPauillac, in Bordeaux's Left Bank Médoc region, boasts well-draining gravel soils, which in turn translates to higher quality wines; and those from Pauillac age extremely well.\n\nThree of the five first-growths from the 1855 classification of the Médoc are situated in Pauillac: Lafite, Latour, and Mouton-Rothschild.",
#      'blurb': None,
#      'interesting_facts': ["Though Pauillac boasts some of Bordeaux's most acclaimed estates, the town itself is very small.",
#       "More than half of the 18 classified 'Fifth-Growths' are in Pauillac, including the famous Château Lynch-Bages.",
#       "Château Mouton-Rothschild, which encompases 90 hectares (222 acres) in Pauillac was elevated from a 'Second-Growth' to a 'First-Growth in 1973—the only time in the history of the 1855 Classification that a winery's classified position was re-evaluated."],
#      'body': 4,
#      'body_description': 'Corsé',
#      'acidity': 3,
#      'acidity_description': 'Élevée',
#      'country': {'code': 'fr',
#       'name': 'France',
#       'native_name': 'France',
#       'seo_name': 'france',
#       'currency': {'code': 'EUR',
#        'name': 'Euros',
#        'prefix': '€',
#        'suffix': None},
#       'regions_count': 1280,
#       'users_count': 3790550,
#       'wines_count': 481923,
#       'wineries_count': 64952,
#       'most_used_grapes': [{'id': 14,
#         'name': 'Pinot Noir',
#         'seo_name': 'pinot-noir',
#         'has_detailed_info': True,
#         'wines_count': 462117},
#        {'id': 10,
#         'name': 'Merlot',
#         'seo_name': 'merlot',
#         'has_detailed_info': True,
#         'wines_count': 461197},
#        {'id': 5,
#         'name': 'Chardonnay',
#         'seo_name': 'chardonnay',
#         'has_detailed_info': True,
#         'wines_count': 487962}]},
#      'wine_type_id': 1,
#      'food': [{'id': 4,
#        'name': 'Beef',
#        'background_image': {'location': '//images.vivino.com/backgrounds/foods/4_beef.png',
#         'variations': {'small': '//images.vivino.com/backgrounds/foods/thumbs/4_beef_932x810.png'}},
#        'seo_name': 'beef'},
#       {'id': 8,
#        'name': 'Lamb',
#        'background_image': {'location': '//images.vivino.com/backgrounds/foods/8_lamb.png',
#         'variations': {'small': '//images.vivino.com/backgrounds/foods/thumbs/8_lamb_932x810.png'}},
#        'seo_name': 'lamb'},
#       {'id': 11,
#        'name': 'Game (deer, venison)',
#        'background_image': {'location': '//images.vivino.com/backgrounds/foods/11_venison.png',
#         'variations': {'small': '//images.vivino.com/backgrounds/foods/thumbs/11_venison_932x810.png'}},
#        'seo_name': 'game'},
#       {'id': 20,
#        'name': 'Poultry',
#        'background_image': {'location': '//images.vivino.com/backgrounds/foods/20_chicken.png',
#         'variations': {'small': '//images.vivino.com/backgrounds/foods/thumbs/20_chicken_932x810.png'}},
#        'seo_name': 'poultry'}],
#      'grapes': [{'id': 2,
#        'name': 'Cabernet Sauvignon',
#        'seo_name': 'cabernet-sauvignon',
#        'has_detailed_info': True,
#        'wines_count': 658524},
#       {'id': 3,
#        'name': 'Cabernet Franc',
#        'seo_name': 'cabernet-franc',
#        'has_detailed_info': True,
#        'wines_count': 219118},
#       {'id': 9,
#        'name': 'Malbec',
#        'seo_name': 'malbec',
#        'has_detailed_info': True,
#        'wines_count': 179553},
#       {'id': 10,
#        'name': 'Merlot',
#        'seo_name': 'merlot',
#        'has_detailed_info': True,
#        'wines_count': 461197},
#       {'id': 42,
#        'name': 'Petit Verdot',
#        'seo_name': 'petit-verdot',
#        'has_detailed_info': True,
#        'wines_count': 68232},
#       {'id': 51,
#        'name': 'Carménère',
#        'seo_name': 'carmenere',
#        'has_detailed_info': True,
#        'wines_count': 41738}],
#      'region': {'id': 383,
#       'name': 'Bordeaux',
#       'name_en': '',
#       'seo_name': 'bordeaux',
#       'country': {'code': 'fr',
#        'name': 'France',
#        'native_name': 'France',
#        'seo_name': 'france',
#        'currency': {'code': 'EUR',
#         'name': 'Euros',
#         'prefix': '€',
#         'suffix': None},
#        'regions_count': 1280,
#        'users_count': 3790550,
#        'wines_count': 481923,
#        'wineries_count': 64952,
#        'most_used_grapes': [{'id': 14,
#          'name': 'Pinot Noir',
#          'seo_name': 'pinot-noir',
#          'has_detailed_info': True,
#          'wines_count': 462117},
#         {'id': 10,
#          'name': 'Merlot',
#          'seo_name': 'merlot',
#          'has_detailed_info': True,
#          'wines_count': 461197},
#         {'id': 5,
#          'name': 'Chardonnay',
#          'seo_name': 'chardonnay',
#          'has_detailed_info': True,
#          'wines_count': 487962}]},
#       'background_image': {'location': '//images.vivino.com/regions/backgrounds/sbzA7h1ITnaHABaVqWJ4CA.jpg',
#        'variations': {'large': '//thumbs.vivino.com/region_backgrounds/sbzA7h1ITnaHABaVqWJ4CA_1280x760.jpg',
#         'medium': '//thumbs.vivino.com/region_backgrounds/sbzA7h1ITnaHABaVqWJ4CA_600x356.jpg'}},
#       'class': {'typecast_map': {'background_image': {}, 'class': {}}}}}}}],
#  'merchant': {'id': 19432,
#   'name': 'Ovinia',
#   'seo_name': 'ovinia',
#   'legal_name': 'OVINIA',
#   'description': 'Livraison offerte dès 250 EUR',
#   'country': {'code': 'fr',
#    'name': 'France',
#    'native_name': 'France',
#    'seo_name': 'france',
#    'currency': {'code': 'EUR', 'name': 'Euros', 'prefix': '€', 'suffix': None},
#    'regions_count': 1280,
#    'users_count': 3790550,
#    'wines_count': 481923,
#    'wineries_count': 64952,
#    'most_used_grapes': [{'id': 14,
#      'name': 'Pinot Noir',
#      'seo_name': 'pinot-noir',
#      'has_detailed_info': True,
#      'wines_count': 462117},
#     {'id': 10,
#      'name': 'Merlot',
#      'seo_name': 'merlot',
#      'has_detailed_info': True,
#      'wines_count': 461197},
#     {'id': 5,
#      'name': 'Chardonnay',
#      'seo_name': 'chardonnay',
#      'has_detailed_info': True,
#      'wines_count': 487962}]},
#   'state': None,
#   'status': 3,
#   'image': {'location': '//images.vivino.com/merchants/originals/p1chkh730000iv8.jpg',
#    'variations': {'large_square': '//images.vivino.com/merchants/thumbs/p1chkh730000iv8_400x400.jpg',
#     'medium_square': '//images.vivino.com/merchants/thumbs/p1chkh730000iv8_320x320.jpg',
#     'small_square': '//images.vivino.com/merchants/thumbs/p1chkh730000iv8_160x160.jpg'}},
#   'shipping_estimate': 'Livraison estimée entre le lun., 31 août et le ven., 04 sept.',
#   'impressum_url': None,
#   'tos_url': 'https://www.ovinia.fr/contact',
#   'payment_options': {'methods': [{'id': 1,
#      'name': 'Stripe',
#      'capabilities': [{'id': 'card_payments',
#        'status': 'active',
#        'object': 'capability',
#        'account': 'acct_19zZhIDBLFYZjaxt',
#        'requested': True,
#        'requested_at': 1578391569,
#        'requirements': {'current_deadline': 0,
#         'currently_due': [],
#         'disabled_reason': '',
#         'eventually_due': [],
#         'past_due': []}},
#       {'id': 'platform_payments',
#        'status': 'active',
#        'object': 'capability',
#        'account': 'acct_19zZhIDBLFYZjaxt',
#        'requested': True,
#        'requested_at': 1578391569,
#        'requirements': {'current_deadline': 0,
#         'currently_due': [],
#         'disabled_reason': '',
#         'eventually_due': [],
#         'past_due': []}}]}]},
#   'hidden': False},
#  'shipping_message': None,
#  'sold_out': False,
#  'available_vintage_year': None,
#  'carts': None,
#  'prices_and_availability': {'market': {'country': 'fr',
#    'currency': {'code': 'EUR',
#     'name': 'Euros',
#     'prefix': '€',
#     'suffix': None}},
#   'availability': {'vintage': {'id': 1831130,
#     'year': 2010,
#     'grapes': None,
#     'has_valid_ratings': False},
#    'median': {'amount': 77.0, 'type': 'market', 'discounted_from': None},
#    'price': {'id': 17010387,
#     'amount': 77.0,
#     'discounted_from': 0.0,
#     'type': 'vc'}},
#   'merchants_with_prices': [{'merchant': {'id': 19432,
#      'name': 'Ovinia',
#      'seo_name': 'ovinia',
#      'legal_name': 'OVINIA',
#      'description': 'Livraison offerte dès 250 EUR',
#      'country': {'code': 'fr',
#       'name': 'France',
#       'native_name': 'France',
#       'seo_name': 'france',
#       'currency': {'code': 'EUR',
#        'name': 'Euros',
#        'prefix': '€',
#        'suffix': None},
#       'regions_count': 1280,
#       'users_count': 3790550,
#       'wines_count': 481923,
#       'wineries_count': 64952,
#       'most_used_grapes': [{'id': 14,
#         'name': 'Pinot Noir',
#         'seo_name': 'pinot-noir',
#         'has_detailed_info': True,
#         'wines_count': 462117},
#        {'id': 10,
#         'name': 'Merlot',
#         'seo_name': 'merlot',
#         'has_detailed_info': True,
#         'wines_count': 461197},
#        {'id': 5,
#         'name': 'Chardonnay',
#         'seo_name': 'chardonnay',
#         'has_detailed_info': True,
#         'wines_count': 487962}]},
#      'state': None,
#      'status': 3,
#      'image': {'location': '//images.vivino.com/merchants/originals/p1chkh730000iv8.jpg',
#       'variations': {'large_square': '//images.vivino.com/merchants/thumbs/p1chkh730000iv8_400x400.jpg',
#        'medium_square': '//images.vivino.com/merchants/thumbs/p1chkh730000iv8_320x320.jpg',
#        'small_square': '//images.vivino.com/merchants/thumbs/p1chkh730000iv8_160x160.jpg'}},
#      'shipping_estimate': 'Livraison estimée entre le lun., 31 août et le ven., 04 sept.',
#      'impressum_url': None,
#      'tos_url': 'https://www.ovinia.fr/contact',
#      'payment_options': {'methods': [{'id': 1,
#         'name': 'Stripe',
#         'capabilities': [{'id': 'card_payments',
#           'status': 'active',
#           'object': 'capability',
#           'account': 'acct_19zZhIDBLFYZjaxt',
#           'requested': True,
#           'requested_at': 1578391569,
#           'requirements': {'current_deadline': 0,
#            'currently_due': [],
#            'disabled_reason': '',
#            'eventually_due': [],
#            'past_due': []}},
#          {'id': 'platform_payments',
#           'status': 'active',
#           'object': 'capability',
#           'account': 'acct_19zZhIDBLFYZjaxt',
#           'requested': True,
#           'requested_at': 1578391569,
#           'requirements': {'current_deadline': 0,
#            'currently_due': [],
#            'disabled_reason': '',
#            'eventually_due': [],
#            'past_due': []}}]}]},
#      'hidden': False},
#     'prices': [{'id': 17010387,
#       'vintage_id': 1831130,
#       'amount': 77,
#       'currency': {'code': 'EUR',
#        'name': 'Euros',
#        'prefix': '€',
#        'suffix': None},
#       'bottle_type_id': 1,
#       'inventory_bottles_count': 576,
#       'url': 'https://club.ovinia.fr/catalogue-vins/?utm_medium=pref-cpc&utm_source=vivino-ppc',
#       'message': 'Prix par bouteille, caisse de 12 bouteilles',
#       'producer_address': None,
#       'importer_address': None,
#       'discounted_from': None,
#       'bottle_type': {'id': 1,
#        'name': 'Bouteille (75cl)',
#        'short_name': 'bouteille',
#        'short_name_plural': 'bouteilles',
#        'volume_ml': 750}}]},
#    {'merchant': {'id': 6688,
#      'name': 'Millesima - France',
#      'seo_name': 'millesima-france',
#      'legal_name': 'MILLESIMA',
#      'description': 'Livraison offerte dès 250 EUR',
#      'country': {'code': 'fr',
#       'name': 'France',
#       'native_name': 'France',
#       'seo_name': 'france',
#       'currency': {'code': 'EUR',
#        'name': 'Euros',
#        'prefix': '€',
#        'suffix': None},
#       'regions_count': 1280,
#       'users_count': 3790550,
#       'wines_count': 481923,
#       'wineries_count': 64952,
#       'most_used_grapes': [{'id': 14,
#         'name': 'Pinot Noir',
#         'seo_name': 'pinot-noir',
#         'has_detailed_info': True,
#         'wines_count': 462117},
#        {'id': 10,
#         'name': 'Merlot',
#         'seo_name': 'merlot',
#         'has_detailed_info': True,
#         'wines_count': 461197},
#        {'id': 5,
#         'name': 'Chardonnay',
#         'seo_name': 'chardonnay',
#         'has_detailed_info': True,
#         'wines_count': 487962}]},
#      'state': None,
#      'status': 3,
#      'image': {'location': '//images.vivino.com/merchants/originals/p1bbkdqp00006h0.png',
#       'variations': {'large_square': '//images.vivino.com/merchants/thumbs/p1bbkdqp00006h0_400x400.jpg',
#        'medium_square': '//images.vivino.com/merchants/thumbs/p1bbkdqp00006h0_320x320.jpg',
#        'small_square': '//images.vivino.com/merchants/thumbs/p1bbkdqp00006h0_160x160.jpg'}},
#      'shipping_estimate': 'Livraison avant le lun., 31 août',
#      'impressum_url': None,
#      'tos_url': 'https://www.millesima.fr/cgv.html#mentions',
#      'payment_options': {'methods': [{'id': 1,
#         'name': 'Stripe',
#         'capabilities': [{'id': 'card_payments',
#           'status': 'active',
#           'object': 'capability',
#           'account': 'acct_19C9CkHKzrIy0UUu',
#           'requested': True,
#           'requested_at': 1578391836,
#           'requirements': {'current_deadline': 0,
#            'currently_due': [],
#            'disabled_reason': '',
#            'eventually_due': [],
#            'past_due': []}},
#          {'id': 'platform_payments',
#           'status': 'active',
#           'object': 'capability',
#           'account': 'acct_19C9CkHKzrIy0UUu',
#           'requested': True,
#           'requested_at': 1578391836,
#           'requirements': {'current_deadline': 0,
#            'currently_due': [],
#            'disabled_reason': '',
#            'eventually_due': [],
#            'past_due': []}}]}]},
#      'hidden': False},
#     'prices': [{'id': 4682283,
#       'vintage_id': 1831130,
#       'amount': 100,
#       'currency': {'code': 'EUR',
#        'name': 'Euros',
#        'prefix': '€',
#        'suffix': None},
#       'bottle_type_id': 4,
#       'inventory_bottles_count': 396,
#       'url': 'https://www.millesima.fr/chateau-pedesclaux-2010-d-cb-6.html?declinaison=d_cb_6&utm_campaign=generique&utm_content=ready for delivery&utm_medium=pref-cpc&utm_source=vivino-ppc&utm_term=chateau pedesclaux 2010 d cb 6',
#       'message': 'Prix par magnum, caisse de 6 bouteilles',
#       'producer_address': None,
#       'importer_address': None,
#       'discounted_from': None,
#       'bottle_type': {'id': 4,
#        'name': 'Magnum (1,5 l)',
#        'short_name': 'magnum',
#        'short_name_plural': 'magnums',
#        'volume_ml': 1500}}]},
#    {'merchant': {'id': 22897,
#      'name': 'Restaurant La Truffiere',
#      'seo_name': 'restaurant-la-truffiere',
#      'legal_name': None,
#      'description': 'No minimum order. Mobile friendly checkout.',
#      'country': {'code': 'fr',
#       'name': 'France',
#       'native_name': 'France',
#       'seo_name': 'france',
#       'currency': {'code': 'EUR',
#        'name': 'Euros',
#        'prefix': '€',
#        'suffix': None},
#       'regions_count': 1280,
#       'users_count': 3790550,
#       'wines_count': 481923,
#       'wineries_count': 64952,
#       'most_used_grapes': [{'id': 14,
#         'name': 'Pinot Noir',
#         'seo_name': 'pinot-noir',
#         'has_detailed_info': True,
#         'wines_count': 462117},
#        {'id': 10,
#         'name': 'Merlot',
#         'seo_name': 'merlot',
#         'has_detailed_info': True,
#         'wines_count': 461197},
#        {'id': 5,
#         'name': 'Chardonnay',
#         'seo_name': 'chardonnay',
#         'has_detailed_info': True,
#         'wines_count': 487962}]},
#      'state': None,
#      'status': 0,
#      'image': None,
#      'shipping_estimate': 'Livraison avant le lun., 31 août',
#      'impressum_url': None,
#      'tos_url': None,
#      'hidden': False},
#     'prices': [{'id': 12368873,
#       'vintage_id': 1831130,
#       'amount': 56,
#       'currency': {'code': 'EUR',
#        'name': 'Euros',
#        'prefix': '€',
#        'suffix': None},
#       'bottle_type_id': 1,
#       'inventory_bottles_count': None,
#       'url': 'https://www.latruffiere-vinotheque.com/fr_FR/taxons/region?page=50&utm_medium=pref-cpc&utm_source=vivino-ppc',
#       'message': '',
#       'producer_address': None,
#       'importer_address': None,
#       'discounted_from': None,
#       'bottle_type': {'id': 1,
#        'name': 'Bouteille (75cl)',
#        'short_name': 'bouteille',
#        'short_name_plural': 'bouteilles',
#        'volume_ml': 750}}]},
#    {'merchant': {'id': 1112,
#      'name': 'FinestWine',
#      'seo_name': 'finestwine',
#      'legal_name': None,
#      'description': 'Mobile friendly checkout. No minimum order.',
#      'country': {'code': 'fr',
#       'name': 'France',
#       'native_name': 'France',
#       'seo_name': 'france',
#       'currency': {'code': 'EUR',
#        'name': 'Euros',
#        'prefix': '€',
#        'suffix': None},
#       'regions_count': 1280,
#       'users_count': 3790550,
#       'wines_count': 481923,
#       'wineries_count': 64952,
#       'most_used_grapes': [{'id': 14,
#         'name': 'Pinot Noir',
#         'seo_name': 'pinot-noir',
#         'has_detailed_info': True,
#         'wines_count': 462117},
#        {'id': 10,
#         'name': 'Merlot',
#         'seo_name': 'merlot',
#         'has_detailed_info': True,
#         'wines_count': 461197},
#        {'id': 5,
#         'name': 'Chardonnay',
#         'seo_name': 'chardonnay',
#         'has_detailed_info': True,
#         'wines_count': 487962}]},
#      'state': None,
#      'status': 0,
#      'image': {'location': '//images.vivino.com/merchants/originals/p1b617u6000012o.jpg',
#       'variations': {'large_square': '//images.vivino.com/merchants/thumbs/p1b617u6000012o_400x400.jpg',
#        'medium_square': '//images.vivino.com/merchants/thumbs/p1b617u6000012o_320x320.jpg',
#        'small_square': '//images.vivino.com/merchants/thumbs/p1b617u6000012o_160x160.jpg'}},
#      'shipping_estimate': 'Livraison avant le lun., 31 août',
#      'impressum_url': None,
#      'tos_url': None,
#      'hidden': False},
#     'prices': [{'id': 9878820,
#       'vintage_id': 1831130,
#       'amount': 84.2,
#       'currency': {'code': 'EUR',
#        'name': 'Euros',
#        'prefix': '€',
#        'suffix': None},
#       'bottle_type_id': 1,
#       'inventory_bottles_count': None,
#       'url': 'http://www.finestwine.com/en/2010/26617-chateau-pedesclaux.html?utm_medium=pref-cpc&utm_source=vivino-ppc',
#       'message': 'Prix par bouteille, caisse de 6 bouteilles',
#       'producer_address': None,
#       'importer_address': None,
#       'discounted_from': None,
#       'bottle_type': {'id': 1,
#        'name': 'Bouteille (75cl)',
#        'short_name': 'bouteille',
#        'short_name_plural': 'bouteilles',
#        'volume_ml': 750}}]}]},
#  'basic_user_vintage': None,
#  'price_range': {'currency': {'code': 'USD',
#    'name': 'US Dollars',
#    'prefix': '$',
#    'suffix': None},
#   'price_range': {'minimum': 0, 'maximum': 500, 'currency_code': 'USD'},
#   'defaults': {'minimum': 10, 'maximum': 40, 'currency_code': 'USD'}},
#  'is_deal_page': False}

# %% [markdown]
# * vintage
#     - name str
#     - statistics dict
#         - status str
#         - ratings_count int
#         - ratings_average float
#         - labels_count int
#         - reviews_count int
#     - organic_certification_id NoneType
#     - certified_biodynamic NoneType
#     - wine dict
#         - id int
#         - name str
#         - type_id int
#         - is_natural bool
#         - region dict
#             - id int
#         - winery dict
#             - id int
#         - statistics dict
#             - status str
#             - ratings_count int
#             - ratings_average float
#             - labels_count int
#             - vintages_count int
#         - rank dict
#             - country dict
#                 - description str
#                 - total int
#                 - rank int
#             - region dict
#                 - description str
#                 - total int
#                 - rank int
#             - winery dict
#                 - description str
#                 - total int
#                 - rank int
#             - wine_type dict
#                 - description str
#                 - total int
#                 - rank int
#             - global dict
#                 - description str
#                 - total int
#                 - rank int
#         - description str
#         - alcohol int
#         - style dict
#             - id int
#             - seo_name str
#             - regional_name str
#             - varietal_name str
#             - name str
#             - image NoneType
#             - background_image dict
#             - description str
#             - blurb NoneType
#             - interesting_facts list
#             - body int
#             - body_description str
#             - acidity int
#             - acidity_description str
#             - country dict
#             - wine_type_id int
#             - food list
#             - grapes list
#             - region dict
#         - has_valid_ratings bool
#     - description str
#     - expert_reviews NoneType
#     - wine_critic_reviews list
#     **list**
#         - id int
#         - wine_critic_id int
#         - score str
#         - score_normalized int
#         - reviewed_at str
#     - awards list
#     - ratings_distribution dict
#         - 1 int
#         - 2 int
#         - 3 int
#         - 4 int
#         - 5 int
#     - ranking dict
#         - country dict
#             - description str
#             - total int
#             - rank int
#         - region dict
#             - description str
#             - total int
#             - rank int
#         - winery dict
#             - description str
#             - total int
#             - rank int
#         - global dict
#             - description str
#             - total int
#             - rank int
#     - wine_facts dict
#     - winemaker NoneType
#     - wine_maker NoneType
#     - grape_composition dict
#     - year int
#     - grapes NoneType
#     - has_valid_ratings bool
# * price
#     - id int
#     - vintage_id int
#     - amount float
#     - currency dict
#         - code str
#         - name str
#         - prefix str
#         - suffix NoneType
#     - bottle_type_id int
#     - inventory_bottles_count NoneType
#     - url str
#     - message str
#     - producer_address NoneType
#     - importer_address NoneType
#     - discounted_from NoneType
#     - bottle_type dict
#         - id int
#         - name str
#         - short_name str
#         - short_name_plural str
#         - volume_ml int
# * highlights
# * merchant
#     - id int
#     - name str
#     - seo_name str
#     - legal_name str
#     - description str
#     - country dict
#         - code str
#         - name str
#         - native_name str
#         - seo_name str
#         - currency dict
#             - code str
#             - name str
#             - prefix str
#             - suffix NoneType
#         - regions_count int
#         - users_count int
#         - wines_count int
#         - wineries_count int
#         - most_used_grapes list
#         **list**
#             - id int
#             - name str
#             - seo_name str
#             - has_detailed_info bool
#             - wines_count int
#     - state NoneType
#     - status int
#     - image dict
#         - location str
#         - variations dict
#     - shipping_estimate str
#     - impressum_url NoneType
#     - tos_url str
#     - payment_options dict
#         - methods list
#         **list**
#             - id int
#             - name str
#             - capabilities list
#             **list**
#                 - id str
#                 - status str
#                 - object str
#                 - account str
#                 - requested bool
#                 - requested_at int
#                 - requirements dict
#                     - current_deadline int
#                     - currently_due list
#                     - disabled_reason str
#                     - eventually_due list
#                     - past_due list
#     - hidden bool
# * shipping_message
# * sold_out
# * available_vintage_year
# * carts
# * prices_and_availability
#     - market dict
#         - country str
#         - currency dict
#             - code str
#             - name str
#             - prefix str
#             - suffix NoneType
#     - availability dict
#         - vintage dict
#             - id int
#             - year int
#             - grapes NoneType
#             - has_valid_ratings bool
#         - median dict
#             - amount float
#             - type str
#             - discounted_from NoneType
#         - price dict
#             - id int
#             - amount float
#             - discounted_from float
#             - type str
#     - merchants_with_prices list
#     **list**
#         - merchant dict
#             - id int
#             - name str
#             - seo_name str
#             - legal_name str
#             - description str
#             - country dict
#                 - code str
#                 - name str
#                 - native_name str
#                 - seo_name str
#                 - currency dict
#                     - code str
#                     - name str
#                     - prefix str
#                     - suffix NoneType
#                 - regions_count int
#                 - users_count int
#                 - wines_count int
#                 - wineries_count int
#                 - most_used_grapes list
#                 **list**
#                     - id int
#                     - name str
#                     - seo_name str
#                     - has_detailed_info bool
#                     - wines_count int
#             - state NoneType
#             - status int
#             - image dict
#                 - location str
#                 - variations dict
#             - shipping_estimate str
#             - impressum_url NoneType
#             - tos_url str
#             - payment_options dict
#                 - methods list
#                 SAME
#             - hidden bool
#         - prices list
#         **list**
#             - id int
#             - vintage_id int
#             - amount float
#             - currency dict
#                 - code str
#                 - name str
#                 - prefix str
#                 - suffix NoneType
#             - bottle_type_id int
#             - inventory_bottles_count NoneType
#             - url str
#             - message str
#             - producer_address NoneType
#             - importer_address NoneType
#             - discounted_from NoneType
#             - bottle_type dict
#                 - id int
#                 - name str
#                 - short_name str
#                 - short_name_plural str
#                 - volume_ml int
# * basic_user_vintage
# * price_range
#     - currency dict
#         - code str
#         - name str
#         - prefix str
#         - suffix NoneType
#     - price_range dict
#         - minimum int
#         - maximum int
#         - currency_code str
#     - defaults dict
#         - minimum int
#         - maximum int
#         - currency_code str
# * is_deal_page

# %% [markdown]
# * vintage
#     - id int
#     - seo_name str
#     - name str
#     - statistics dict
#         - status str
#         - ratings_count int
#         - ratings_average float
#         - labels_count int
#         - reviews_count int
#     - organic_certification_id NoneType
#     - certified_biodynamic NoneType
#     - image dict
#         - location str
#         - variations dict
#             - bottle_large str
#             - bottle_medium str
#             - bottle_medium_square str
#             - bottle_small str
#             - bottle_small_square str
#             - label str
#             - label_large str
#             - label_medium str
#             - label_medium_square str
#             - label_small_square str
#             - large str
#             - medium str
#             - medium_square str
#             - small_square str
#     - wine dict
#         - id int
#         - name str
#         - seo_name str
#         - type_id int
#         - vintage_type int
#         - is_natural bool
#         - region dict
#             - id int
#             - name str
#             - name_en str
#             - seo_name str
#             - country dict
#                 - code str
#                 - name str
#                 - native_name str
#                 - seo_name str
#                 - currency dict
#                     - code str
#                     - name str
#                     - prefix str
#                     - suffix NoneType
#                 - regions_count int
#                 - users_count int
#                 - wines_count int
#                 - wineries_count int
#                 - most_used_grapes list
#             - background_image dict
#                 - location str
#                 - variations dict
#             - class dict
#                 - typecast_map dict
#                     - background_image dict
#                     - class dict
#         - review_status int
#         - winery dict
#             - id int
#             - name str
#             - seo_name str
#             - status int
#             - review_status str
#             - statistics dict
#                 - ratings_count int
#                 - ratings_average float
#                 - labels_count int
#                 - wines_count int
#             - region dict
#                 - id int
#                 - name str
#                 - name_en str
#                 - seo_name str
#                 - country dict
#                     same
#                 - background_image dict
#                     same
#                 - class dict
#             - business_name str
#             - description str
#             - phone str
#             - email str
#             - facebook str
#             - instagram str
#             - is_claimed bool
#             - twitter str
#             - website str
#             - winemaker str
#             - wine_maker dict
#                 - id int
#                 - name str
#             - address dict
#                 - title NoneType
#                 - name NoneType
#                 - street str
#                 - street2 NoneType
#                 - neighborhood NoneType
#                 - city str
#                 - zip str
#                 - state NoneType
#                 - country dict
#                 - company NoneType
#                 - phone NoneType
#                 - external_id NoneType
#                 - residential NoneType
#                 - vat_number NoneType
#                 - vat_code NoneType
#                 - addition NoneType
#             - image NoneType
#             - background_image NoneType
#             - location dict
#                 - latitude float
#                 - longitude float
#             - winery_group NoneType
#             - first_wines list
#                 **list**
#                     - id int
#                     - name str
#                     - seo_name str
#                     - type_id int
#                     - vintage_type int
#                     - is_natural bool
#                     - region NoneType
#                     - review_status int
#         - statistics dict
#             - status str
#             - ratings_count int
#             - ratings_average float
#             - labels_count int
#             - vintages_count int
#         - rank dict
#             - country dict
#                 - description str
#                 - total int
#                 - rank int
#             - region dict
#                 - description str
#                 - total int
#                 - rank int
#             - winery dict
#                 - description str
#                 - total int
#                 - rank int
#             - wine_type dict
#                 - description str
#                 - total int
#                 - rank int
#             - global dict
#                 - description str
#                 - total int
#                 - rank int
#         - hidden bool
#         - vintages list
#         **list**
#             - id int
#             - seo_name str
#             - name str
#             - statistics dict
#                 - status str
#                 - ratings_count int
#                 - ratings_average float
#                 - labels_count int
#                 - reviews_count int
#             - year str
#             - grapes NoneType
#             - has_valid_ratings bool
#         - description str
#         - grapes list
#         **list**
#             - id int
#             - name str
#             - seo_name str
#             - has_detailed_info bool
#             - wines_count int
#         - foods list
#         **list**
#             - id int
#             - name str
#             - background_image dict
#             - seo_name str
#         - non_vintage bool
#         - alcohol int
#         - sweetness_id NoneType
#         - vintage_mask_raw NoneType
#         - created_at str
#         - is_first_wine bool
#         - style dict
#             - id int
#             - seo_name str
#             - regional_name str
#             - varietal_name str
#             - name str
#             - image NoneType
#             - background_image dict
#             - description str
#             - blurb NoneType
#             - interesting_facts list
#             - body int
#             - body_description str
#             - acidity int
#             - acidity_description str
#             - country dict
#             - wine_type_id int
#             - food list
#             - grapes list
#             - region dict
#         - has_valid_ratings bool
#     - description str
#     - expert_reviews NoneType
#     - wine_critic_reviews list
#     **list**
#         - id int
#         - wine_critic_id int
#         - score str
#         - score_normalized int
#         - reviewed_at str
#     - awards list
#     - ratings_distribution dict
#         - 1 int
#         - 2 int
#         - 3 int
#         - 4 int
#         - 5 int
#     - ranking dict
#         - country dict
#             - description str
#             - total int
#             - rank int
#         - region dict
#             - description str
#             - total int
#             - rank int
#         - winery dict
#             - description str
#             - total int
#             - rank int
#         - global dict
#             - description str
#             - total int
#             - rank int
#     - wine_facts dict
#     - winemaker NoneType
#     - wine_maker NoneType
#     - grape_composition dict
#     - year int
#     - grapes NoneType
#     - has_valid_ratings bool
# * price
#     - id int
#     - vintage_id int
#     - amount float
#     - currency dict
#         - code str
#         - name str
#         - prefix str
#         - suffix NoneType
#     - bottle_type_id int
#     - inventory_bottles_count NoneType
#     - url str
#     - message str
#     - producer_address NoneType
#     - importer_address NoneType
#     - discounted_from NoneType
#     - bottle_type dict
#         - id int
#         - name str
#         - short_name str
#         - short_name_plural str
#         - volume_ml int
# * highlights
# * merchant
#     - id int
#     - name str
#     - seo_name str
#     - legal_name str
#     - description str
#     - country dict
#         - code str
#         - name str
#         - native_name str
#         - seo_name str
#         - currency dict
#             - code str
#             - name str
#             - prefix str
#             - suffix NoneType
#         - regions_count int
#         - users_count int
#         - wines_count int
#         - wineries_count int
#         - most_used_grapes list
#         **list**
#             - id int
#             - name str
#             - seo_name str
#             - has_detailed_info bool
#             - wines_count int
#     - state NoneType
#     - status int
#     - image dict
#         - location str
#         - variations dict
#     - shipping_estimate str
#     - impressum_url NoneType
#     - tos_url str
#     - payment_options dict
#         - methods list
#         **list**
#             - id int
#             - name str
#             - capabilities list
#             **list**
#                 - id str
#                 - status str
#                 - object str
#                 - account str
#                 - requested bool
#                 - requested_at int
#                 - requirements dict
#                     - current_deadline int
#                     - currently_due list
#                     - disabled_reason str
#                     - eventually_due list
#                     - past_due list
#     - hidden bool
# * shipping_message
# * sold_out
# * available_vintage_year
# * carts
# * prices_and_availability
#     - market dict
#         - country str
#         - currency dict
#             - code str
#             - name str
#             - prefix str
#             - suffix NoneType
#     - availability dict
#         - vintage dict
#             - id int
#             - year int
#             - grapes NoneType
#             - has_valid_ratings bool
#         - median dict
#             - amount float
#             - type str
#             - discounted_from NoneType
#         - price dict
#             - id int
#             - amount float
#             - discounted_from float
#             - type str
#     - merchants_with_prices list
#     **list**
#         - merchant dict
#             - id int
#             - name str
#             - seo_name str
#             - legal_name str
#             - description str
#             - country dict
#                 - code str
#                 - name str
#                 - native_name str
#                 - seo_name str
#                 - currency dict
#                     - code str
#                     - name str
#                     - prefix str
#                     - suffix NoneType
#                 - regions_count int
#                 - users_count int
#                 - wines_count int
#                 - wineries_count int
#                 - most_used_grapes list
#                 **list**
#                     - id int
#                     - name str
#                     - seo_name str
#                     - has_detailed_info bool
#                     - wines_count int
#             - state NoneType
#             - status int
#             - image dict
#                 - location str
#                 - variations dict
#             - shipping_estimate str
#             - impressum_url NoneType
#             - tos_url str
#             - payment_options dict
#                 - methods list
#                 SAME
#             - hidden bool
#         - prices list
#         **list**
#             - id int
#             - vintage_id int
#             - amount float
#             - currency dict
#                 - code str
#                 - name str
#                 - prefix str
#                 - suffix NoneType
#             - bottle_type_id int
#             - inventory_bottles_count NoneType
#             - url str
#             - message str
#             - producer_address NoneType
#             - importer_address NoneType
#             - discounted_from NoneType
#             - bottle_type dict
#                 - id int
#                 - name str
#                 - short_name str
#                 - short_name_plural str
#                 - volume_ml int
# * basic_user_vintage
# * price_range
#     - currency dict
#         - code str
#         - name str
#         - prefix str
#         - suffix NoneType
#     - price_range dict
#         - minimum int
#         - maximum int
#         - currency_code str
#     - defaults dict
#         - minimum int
#         - maximum int
#         - currency_code str
# * is_deal_page

# %%
sample['vintage']['id']
# Out:
# 3234396

# %%
for i in los[:5]:
    for j,k in i.items():
        if isinstance(k,dict):
            print(k.keys())
        else:
            print(j)
# Out:
# dict_keys(['id', 'seo_name', 'name', 'statistics', 'organic_certification_id', 'certified_biodynamic', 'image', 'wine', 'description', 'expert_reviews', 'wine_critic_reviews', 'awards', 'ratings_distribution', 'ranking', 'top_list_rankings', 'wine_facts', 'winemaker', 'wine_maker', 'grape_composition', 'year', 'grapes', 'has_valid_ratings'])
# dict_keys(['id', 'vintage_id', 'amount', 'currency', 'bottle_type_id', 'inventory_bottles_count', 'bottles_sold_count', 'url', 'message', 'producer_address', 'importer_address', 'discounted_from', 'bottle_type'])
# highlights
# dict_keys(['id', 'name', 'seo_name', 'legal_name', 'description', 'country', 'state', 'status', 'image', 'shipping_estimate', 'impressum_url', 'tos_url', 'payment_options', 'hidden'])
# shipping_message
# sold_out
# available_vintage_year
# carts
# dict_keys(['market', 'availability', 'merchants_with_prices'])
# basic_user_vintage
# dict_keys(['currency', 'price_range', 'defaults'])
# is_deal_page
# dict_keys(['id', 'seo_name', 'name', 'statistics', 'organic_certification_id', 'certified_biodynamic', 'image', 'wine', 'description', 'expert_reviews', 'wine_critic_reviews', 'awards', 'ratings_distribution', 'ranking', 'top_list_rankings', 'wine_facts', 'winemaker', 'wine_maker', 'grape_composition', 'year', 'grapes', 'has_valid_ratings'])
# dict_keys(['id', 'vintage_id', 'amount', 'currency', 'bottle_type_id', 'inventory_bottles_count', 'url', 'message', 'producer_address', 'importer_address', 'discounted_from', 'bottle_type'])
# highlights
# dict_keys(['id', 'name', 'seo_name', 'legal_name', 'description', 'country', 'state', 'status', 'image', 'shipping_estimate', 'impressum_url', 'tos_url', 'hidden'])
# shipping_message
# sold_out
# available_vintage_year
# carts
# dict_keys(['market', 'availability', 'merchants_with_prices'])
# basic_user_vintage
# dict_keys(['currency', 'price_range', 'defaults'])
# is_deal_page
# dict_keys(['id', 'seo_name', 'name', 'statistics', 'organic_certification_id', 'certified_biodynamic', 'image', 'wine', 'description', 'expert_reviews', 'wine_critic_reviews', 'awards', 'ratings_distribution', 'ranking', 'wine_facts', 'winemaker', 'wine_maker', 'grape_composition', 'year', 'grapes', 'has_valid_ratings'])
# dict_keys(['id', 'vintage_id', 'amount', 'currency', 'bottle_type_id', 'inventory_bottles_count', 'url', 'message', 'producer_address', 'importer_address', 'discounted_from', 'bottle_type'])
# highlights
# dict_keys(['id', 'name', 'seo_name', 'legal_name', 'description', 'country', 'state', 'status', 'image', 'shipping_estimate', 'impressum_url', 'tos_url', 'payment_options', 'hidden'])
# shipping_message
# sold_out
# available_vintage_year
# carts
# dict_keys(['market', 'availability', 'merchants_with_prices'])
# basic_user_vintage
# dict_keys(['currency', 'price_range', 'defaults'])
# is_deal_page
# dict_keys(['id', 'seo_name', 'name', 'statistics', 'organic_certification_id', 'certified_biodynamic', 'image', 'wine', 'description', 'expert_reviews', 'wine_critic_reviews', 'awards', 'ratings_distribution', 'ranking', 'wine_facts', 'winemaker', 'wine_maker', 'grape_composition', 'year', 'grapes', 'has_valid_ratings'])
# dict_keys(['id', 'vintage_id', 'amount', 'currency', 'bottle_type_id', 'inventory_bottles_count', 'bottles_sold_count', 'url', 'message', 'producer_address', 'importer_address', 'discounted_from', 'bottle_type'])
# highlights
# dict_keys(['id', 'name', 'seo_name', 'legal_name', 'description', 'country', 'state', 'status', 'image', 'shipping_estimate', 'impressum_url', 'tos_url', 'payment_options', 'hidden'])
# shipping_message
# sold_out
# available_vintage_year
# carts
# dict_keys(['market', 'availability', 'merchants_with_prices'])
# basic_user_vintage
# dict_keys(['currency', 'price_range', 'defaults'])
# is_deal_page
# dict_keys(['id', 'seo_name', 'name', 'statistics', 'organic_certification_id', 'certified_biodynamic', 'image', 'wine', 'description', 'expert_reviews', 'wine_critic_reviews', 'awards', 'ratings_distribution', 'ranking', 'wine_facts', 'winemaker', 'wine_maker', 'grape_composition', 'year', 'grapes', 'has_valid_ratings'])
# dict_keys(['id', 'vintage_id', 'amount', 'currency', 'bottle_type_id', 'inventory_bottles_count', 'bottles_sold_count', 'url', 'message', 'producer_address', 'importer_address', 'discounted_from', 'bottle_type'])
# highlights
# dict_keys(['id', 'name', 'seo_name', 'legal_name', 'description', 'country', 'state', 'status', 'image', 'shipping_estimate', 'impressum_url', 'tos_url', 'payment_options', 'hidden'])
# shipping_message
# sold_out
# available_vintage_year
# carts
# dict_keys(['market', 'availability', 'merchants_with_prices'])
# basic_user_vintage
# dict_keys(['currency', 'price_range', 'defaults'])
# is_deal_page

# %%
print(list_of_keys_vintage)
# Out:
# {'vintage', 'price_range', 'prices_and_availability', 'merchant', 'is_deal_page', 'shipping_message', 'highlights', 'sold_out', 'basic_user_vintage', 'carts', 'price', 'available_vintage_year'}

# %% [markdown]
# # Table generation

# %% [markdown]
# ## Wines

# %%
sample['vintage'].keys()
# Out:
# dict_keys(['id', 'seo_name', 'name', 'statistics', 'organic_certification_id', 'certified_biodynamic', 'image', 'wine', 'description', 'expert_reviews', 'wine_critic_reviews', 'awards', 'ratings_distribution', 'ranking', 'top_list_rankings', 'wine_facts', 'winemaker', 'wine_maker', 'grape_composition', 'year', 'grapes', 'has_valid_ratings'])

# %%
sample['vintage']['wine'];

# %%
wines=[{key:sample['vintage'][key] for key in ('id', 'name', 'organic_certification_id', 'certified_biodynamic', 
 'wine', 'description', 'expert_reviews', 'wine_critic_reviews', 'awards', 'ratings_distribution', 
 'ranking', 'top_list_rankings', 'wine_facts', 'grape_composition', 'year',
 'grapes', 'has_valid_ratings') if key in sample['vintage'].keys()}  for sample in los]

# %%
wines_df=pd.DataFrame(wines)

# %%
wines_df.to_csv('wines_df')

# %%
wines_df.head()
# Out:
#           id                                  name organic_certification_id  \
# 0   14201617  Marqués de Riscal Rioja Reserva 2015                     None
# 1  150296971                    Catena Malbec 2017                     None
# 2  164942685                Opus One Overture N.V.                     None
# 3   14152059   E. Guigal Côtes-du-Rhône Rouge 2015                     None
# 4   85846548      Mouton Cadet Bordeaux Rouge 2016                     None
#
#   certified_biodynamic                                               wine  \
# 0                False  {'id': 1163903, 'name': 'Rioja Reserva', 'seo_...
# 1                False  {'id': 1873, 'name': 'Malbec', 'seo_name': 'ma...
# 2                False  {'id': 4848, 'name': 'Overture', 'seo_name': '...
# 3                False  {'id': 7773, 'name': 'Côtes-du-Rhône Rouge', '...
# 4                False  {'id': 4113, 'name': 'Bordeaux Rouge', 'seo_na...
#
#   description expert_reviews  \
# 0                       None
# 1                       None
# 2                       None
# 3                       None
# 4                       None
#
#                                  wine_critic_reviews awards  \
# 0  [{'id': 3505777, 'wine_critic_id': 130, 'score...     []
# 1  [{'id': 3005399, 'wine_critic_id': 15, 'score'...     []
# 2  [{'id': 1969143, 'wine_critic_id': 33, 'score'...     []
# 3  [{'id': 1811174, 'wine_critic_id': 1, 'score':...     []
# 4                                                 []     []
#
#                                 ratings_distribution  \
# 0  {'1': 55, '2': 182, '3': 2202, '4': 7868, '5':...
# 1  {'1': 91, '2': 161, '3': 1948, '4': 7616, '5':...
# 2  {'1': 63, '2': 83, '3': 743, '4': 6001, '5': 4...
# 3  {'1': 128, '2': 457, '3': 4800, '4': 4411, '5'...
# 4  {'1': 224, '2': 809, '3': 4910, '4': 3465, '5'...
#
#                                              ranking  \
# 0  {'country': {'description': 'Classement en/au ...
# 1  {'country': {'description': 'Classement en/au ...
# 2  {'country': {'description': 'Classement en/au ...
# 3  {'country': {'description': 'Classement en/au ...
# 4  {'country': {'description': 'Classement en/au ...
#
#                                    top_list_rankings  \
# 0  [{'rank': 4, 'previous_rank': 4, 'description'...
# 1  [{'rank': 2, 'previous_rank': 2, 'description'...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                           wine_facts  \
# 0  {'alcohol': 14, 'residual_sugar_grams_per_lite...
# 1  {'alcohol': 13.5, 'acidity_grams_per_liter': 5...
# 2  {'alcohol': 14.5, 'contains_added_sulfites': T...
# 3  {'alcohol': 14, 'contains_added_sulfites': Tru...
# 4  {'alcohol': 13.5, 'residual_sugar_grams_per_li...
#
#                               grape_composition  year  \
# 0                                   {'19': 100}  2015
# 1                                    {'9': 100}  2017
# 2  {'10': 0, '2': 100, '3': 0, '42': 0, '9': 0}  N.V.
# 3                  {'1': 50, '22': 10, '8': 40}  2015
# 4                   {'10': 83, '2': 10, '3': 7}  2016
#
#                                               grapes  has_valid_ratings
# 0  [{'id': 19, 'name': 'Tempranillo', 'seo_name':...               True
# 1  [{'id': 9, 'name': 'Malbec', 'seo_name': 'malb...               True
# 2  [{'id': 10, 'name': 'Merlot', 'seo_name': 'mer...               True
# 3  [{'id': 1, 'name': 'Shiraz/Syrah', 'seo_name':...               True
# 4  [{'id': 10, 'name': 'Merlot', 'seo_name': 'mer...               True

# %%
with (open("wine_tbm.pkl", "wb")) as openfile:
    pickle.dump(wines_df,openfile)

# %% [markdown]
# ## sm
