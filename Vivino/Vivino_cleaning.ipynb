# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#JSON-insights" data-toc-modified-id="JSON-insights-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>JSON insights</a></span><ul class="toc-item"><li><span><a href="#random" data-toc-modified-id="random-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>random</a></span></li><li><span><a href="#JSON-TREE" data-toc-modified-id="JSON-TREE-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>JSON TREE</a></span></li></ul></li><li><span><a href="#Table-generation" data-toc-modified-id="Table-generation-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Table generation</a></span><ul class="toc-item"><li><span><a href="#Wines" data-toc-modified-id="Wines-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Wines</a></span></li><li><span><a href="#regions" data-toc-modified-id="regions-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>regions</a></span></li><li><span><a href="#wine-body" data-toc-modified-id="wine-body-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>wine body</a></span></li><li><span><a href="#acidity" data-toc-modified-id="acidity-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>acidity</a></span></li><li><span><a href="#meat_info" data-toc-modified-id="meat_info-2.5"><span class="toc-item-num">2.5&nbsp;&nbsp;</span>meat_info</a></span></li><li><span><a href="#wine-meat" data-toc-modified-id="wine-meat-2.6"><span class="toc-item-num">2.6&nbsp;&nbsp;</span>wine meat</a></span></li><li><span><a href="#country" data-toc-modified-id="country-2.7"><span class="toc-item-num">2.7&nbsp;&nbsp;</span>country</a></span></li><li><span><a href="#wine-grapes" data-toc-modified-id="wine-grapes-2.8"><span class="toc-item-num">2.8&nbsp;&nbsp;</span>wine grapes</a></span></li><li><span><a href="#prices" data-toc-modified-id="prices-2.9"><span class="toc-item-num">2.9&nbsp;&nbsp;</span>prices</a></span></li><li><span><a href="#appelation" data-toc-modified-id="appelation-2.10"><span class="toc-item-num">2.10&nbsp;&nbsp;</span>appelation</a></span></li><li><span><a href="#winery" data-toc-modified-id="winery-2.11"><span class="toc-item-num">2.11&nbsp;&nbsp;</span>winery</a></span></li><li><span><a href="#merchants" data-toc-modified-id="merchants-2.12"><span class="toc-item-num">2.12&nbsp;&nbsp;</span>merchants</a></span></li><li><span><a href="#grapes" data-toc-modified-id="grapes-2.13"><span class="toc-item-num">2.13&nbsp;&nbsp;</span>grapes</a></span></li><li><span><a href="#wine-critics" data-toc-modified-id="wine-critics-2.14"><span class="toc-item-num">2.14&nbsp;&nbsp;</span>wine critics</a></span></li></ul></li></ul></div>

# %%
import os

# %%
import pandas as pd

# %%
import pickle

# %%
los = []
with (open("vivino_scripts.pkl", "rb")) as openfile:
    while True:
        try:
            los=pickle.load(openfile)
        except EOFError:
            break

# %%
import re
import json

# %%
los=[json.loads(re.findall(r'window.__PRELOADED_STATE__.+?= (\{\".*?\});?\n',i)[0]) for i in los]

# %%
import random

# %% [markdown]
# # JSON insights

# %% [markdown]
# ## random

# %%
max((len(i.keys()) for i in los))
# Out:
# 12

# %%
min((len(i.keys()) for i in los))
# Out:
# 12

# %%
list_of_keys_1=los[0].keys()

# %%
list_of_keys_1
# Out:
# dict_keys(['vintage', 'price', 'highlights', 'merchant', 'shipping_message', 'sold_out', 'available_vintage_year', 'carts', 'prices_and_availability', 'basic_user_vintage', 'price_range', 'is_deal_page'])

# %%
max((len(i['vintage'].keys()) for i in los))
# Out:
# 22

# %%
min((len(i['vintage'].keys()) for i in los))
# Out:
# 21

# %%
los[0].keys()
# Out:
# dict_keys(['vintage', 'price', 'highlights', 'merchant', 'shipping_message', 'sold_out', 'available_vintage_year', 'carts', 'prices_and_availability', 'basic_user_vintage', 'price_range', 'is_deal_page'])

# %%
sample.keys()
# Out:
# dict_keys(['vintage', 'price', 'highlights', 'merchant', 'shipping_message', 'sold_out', 'available_vintage_year', 'carts', 'prices_and_availability', 'basic_user_vintage', 'price_range', 'is_deal_page'])

# %%
def enjoy(l):
    print('\n'.join(['- '+i+f' {str(type(l[i]))[8:-2]}' for i in l.keys()]))
    return None

# %%
str(type(sample['vintage']['statistics']))[8:-2]
# Out:
# 'dict'

# %%
enjoy(sample['price_range']['defaults'])
# Out:
# - minimum int
# - maximum int
# - currency_code str

# %% [markdown]
# ## JSON TREE

# %%
# read the dataset of links
with open('wines_vivino.txt','r') as f:
    lurl=f.readlines()

# %%
def get_new_link(los=los, lurl=lurl):
    random_index=random.sample(range(len(los)),1)[0]
    sample=los[random_index]
    
    # get the link of sample
    print('https://www.vivino.com'+lurl[random_index])
    return sample

# %%
sample=get_new_link()
sample['vintage']['awards']
# Out:
# https://www.vivino.com/meyney-saint-estephe/w/82831?year=2013&price_id=339793
# [{'id': 69823,
#   'competition_id': 5,
#   'vintage_id': 0,
#   'edition': '2017',
#   'medal': 'Excellent',
#   'trophy': None,
#   'score': None}]

# %% [markdown]
# * vintage
#     - name str
#     - statistics dict
#         - status str
#         - ratings_count int
#         - ratings_average float
#         - labels_count int
#         - reviews_count int
#     - organic_certification_id NoneType
#     - certified_biodynamic NoneType
#     - wine dict
#         - id int
#         - name str
#         - type_id int
#         - is_natural bool
#         - region dict
#             - id int
#         - winery dict
#             - id int
#         - statistics dict
#             - status str
#             - ratings_count int
#             - ratings_average float
#             - labels_count int
#             - vintages_count int
#         - rank dict
#             - country dict
#                 - description str
#                 - total int
#                 - rank int
#             - region dict
#                 - description str
#                 - total int
#                 - rank int
#             - winery dict
#                 - description str
#                 - total int
#                 - rank int
#             - wine_type dict
#                 - description str
#                 - total int
#                 - rank int
#             - global dict
#                 - description str
#                 - total int
#                 - rank int
#         - description str
#         - alcohol int
#         - style dict
#             - id int
#     - description str
#     - awards list
#     - ratings_distribution dict
#         - 1 int
#         - 2 int
#         - 3 int
#         - 4 int
#         - 5 int
#     - ranking dict
#         - country dict
#             - description str
#             - total int
#             - rank int
#         - region dict
#             - description str
#             - total int
#             - rank int
#         - winery dict
#             - description str
#             - total int
#             - rank int
#         - global dict
#             - description str
#             - total int
#             - rank int
#     - wine_facts dict
#     - year int
# * prices_and_availability
#     - availability dict
#         - median dict
#             - amount float

# %% [markdown]
# # Table generation

# %% [markdown]
# ## Wines

# %%
def get_data(x,y):
    """
    x - sample
    y - text query: key.key.key...
    """
    
    try:
        key_path=''.join([str([i]) for i in y.split('.')])
        return eval(str(x)+key_path)
    except:
        return None

# %%
def get_wine(sample):
    return {
    'vintage_id':get_data(sample,'vintage.id'),
    'name':get_data(sample,'vintage.name'),
    'certified_biodynamic':get_data(sample,'vintage.certified_biodynamic'),
    'wine_id':get_data(sample,'vintage.wine.id'),
    'wine_name':get_data(sample,'vintage.wine.name'),
    'type':'Red' if get_data(sample,'vintage.wine.type_id')==1 else 'White',
    'is_natural':get_data(sample,'vintage.wine.is_natural'),
    'region_id':get_data(sample,'vintage.wine.region.id'),
    'country':get_data(sample,'vintage.wine.region.country.name'),
    'winery_id':get_data(sample,'vintage.wine.winery.id'),
    'rank_percentile_country':round(get_data(sample,'vintage.wine.rank.country.rank')/get_data(sample,'vintage.wine.rank.country.total')*100,2) if get_data(sample,'vintage.wine.rank.country.total') else None,
    'rank_percentile_region':round(get_data(sample,'vintage.wine.rank.region.rank')/get_data(sample,'vintage.wine.rank.region.total')*100,2) if get_data(sample,'vintage.wine.rank.region.total') else None,
    'rank_percentile_winery':round(get_data(sample,'vintage.wine.rank.winery.rank')/get_data(sample,'vintage.wine.rank.winery.total')*100,2) if get_data(sample,'vintage.wine.rank.winery.total') else None,
    'rank_percentile_wine_type':round(get_data(sample,'vintage.wine.rank.wine_type.rank')/get_data(sample,'vintage.wine.rank.wine_type.total')*100,2) if get_data(sample,'vintage.wine.rank.wine_type.total') else None,
    'rank_percentile_global':round(get_data(sample,'vintage.wine.rank.global.rank')/get_data(sample,'vintage.wine.rank.global.total')*100,2) if get_data(sample,'vintage.wine.rank.global.total') else None,
    'wine_description':get_data(sample,'vintage.wine.description'),
    'alcohol':get_data(sample,'vintage.wine.alcohol') if get_data(sample,'vintage.wine.alcohol') else get_data(sample,'vintage.wine_facts.alcohol') if get_data(sample,'vintage.wine_facts.alcohol') else None,
    'appelation_id':get_data(sample,'vintage.wine.style.id'),
    'body_id':get_data(sample, 'vintage.wine.style.body'),
    'acidity_id':get_data(sample, 'vintage.wine.style.acidity'),
    'awards_number':len(get_data(sample,'vintage.awards')),
    'awards_bronze_number':sum([True for i in get_data(sample,'vintage.awards') if get_data(sample,'vintage.awards') and i['medal']=='Bronze']),
    'awards_silver_number':sum([True for i in get_data(sample,'vintage.awards') if get_data(sample,'vintage.awards') and i['medal']=='Silver']),
    'awards_gold_number':sum([True for i in get_data(sample,'vintage.awards') if get_data(sample,'vintage.awards') and i['medal']=='Gold']),
    'awards_excellent_number':sum([True for i in get_data(sample,'vintage.awards') if get_data(sample,'vintage.awards') and i['medal']=='Excellent']),
    'awards_platinum_number':sum([True for i in get_data(sample,'vintage.awards') if get_data(sample,'vintage.awards') and i['medal']=='Platinum']),
    'awards_remarkable_number':sum([True for i in get_data(sample,'vintage.awards') if get_data(sample,'vintage.awards') and i['medal']=='Remarkable']),
    'awards_commended_number':sum([True for i in get_data(sample,'vintage.awards') if get_data(sample,'vintage.awards') and i['medal']=='Commended']),
    'ratings_distribution_1':get_data(sample,'vintage.ratings_distribution.1'),
    'ratings_distribution_2':get_data(sample,'vintage.ratings_distribution.2'),
    'ratings_distribution_3':get_data(sample,'vintage.ratings_distribution.3'),
    'ratings_distribution_4':get_data(sample,'vintage.ratings_distribution.4'),
    'ratings_distribution_5':get_data(sample,'vintage.ratings_distribution.5'),
    'vintage_rank_percentile_country':round(get_data(sample,'vintage.ranking.country.rank')/get_data(sample,'vintage.ranking.country.total')*100,2),
    'vintage_rank_percentile_region':round(get_data(sample,'vintage.ranking.region.rank')/get_data(sample,'vintage.ranking.region.total')*100,2),
    'vintage_rank_percentile_winery':round(get_data(sample,'vintage.ranking.winery.rank')/get_data(sample,'vintage.ranking.winery.total')*100,2),
    'vintage_rank_percentile_global':round(get_data(sample,'vintage.ranking.global.rank')/get_data(sample,'vintage.ranking.global.total')*100,2),
    'contains_added_sulfites':get_data(sample, 'vintage.wine_facts.contains_added_sulfites'),
    'contains_milk_allergens':get_data(sample, 'vintage.wine_facts.contains_milk_allergens'),
    'contains_egg_allergens':get_data(sample, 'vintage.wine_facts.contains_egg_allergens'),
    'closure':get_data(sample, 'vintage.wine_facts.closure'),
    'year':get_data(sample, 'vintage.year'),
    'median_price':get_data(sample, 'prices_and_availability.availability.median.amount')

}

# %%
data={}
tot=len(los)
for ix,i in enumerate(los):
    data[ix]=get_wine(i)
    if ix%10==0:
        print(ix/tot)
# Out:
# 0.0
# 0.002777777777777778
# 0.005555555555555556
# 0.008333333333333333
# 0.011111111111111112
# 0.013888888888888888
# 0.016666666666666666
# 0.019444444444444445
# 0.022222222222222223
# 0.025
# 0.027777777777777776
# 0.030555555555555555
# 0.03333333333333333
# 0.03611111111111111
# 0.03888888888888889
# 0.041666666666666664
# 0.044444444444444446
# 0.04722222222222222
# 0.05
# 0.05277777777777778
# 0.05555555555555555
# 0.058333333333333334
# 0.06111111111111111
# 0.06388888888888888
# 0.06666666666666667
# 0.06944444444444445
# 0.07222222222222222
# 0.075
# 0.07777777777777778
# 0.08055555555555556
# 0.08333333333333333
# 0.08611111111111111
# 0.08888888888888889
# 0.09166666666666666
# 0.09444444444444444
# 0.09722222222222222
# 0.1
# 0.10277777777777777
# 0.10555555555555556
# 0.10833333333333334
# 0.1111111111111111
# 0.11388888888888889
# 0.11666666666666667
# 0.11944444444444445
# 0.12222222222222222
# 0.125
# 0.12777777777777777
# 0.13055555555555556
# ...

# %%
wine_df=pd.DataFrame.from_dict(data, orient='index')

# %%
wine_df.to_csv('wine_df_fin.csv')

# %% [markdown]
# ## regions

# %%
def get_regions(sample):
    return {
    'region_id':get_data(sample, 'vintage.wine.region.id'),
    'name_en':get_data(sample, 'vintage.wine.region.name'),
    'country':get_data(sample,'vintage.wine.region.country.native_name')
}

# %%
data={}
tot=len(los)
for ix,i in enumerate(los):
    data[ix]=get_regions(i)
    if ix%100==0:
        print(ix/tot)
# Out:
# 0.0
# 0.027777777777777776
# 0.05555555555555555
# 0.08333333333333333
# 0.1111111111111111
# 0.1388888888888889
# 0.16666666666666666
# 0.19444444444444445
# 0.2222222222222222
# 0.25
# 0.2777777777777778
# 0.3055555555555556
# 0.3333333333333333
# 0.3611111111111111
# 0.3888888888888889
# 0.4166666666666667
# 0.4444444444444444
# 0.4722222222222222
# 0.5
# 0.5277777777777778
# 0.5555555555555556
# 0.5833333333333334
# 0.6111111111111112
# 0.6388888888888888
# 0.6666666666666666
# 0.6944444444444444
# 0.7222222222222222
# 0.75
# 0.7777777777777778
# 0.8055555555555556
# 0.8333333333333334
# 0.8611111111111112
# 0.8888888888888888
# 0.9166666666666666
# 0.9444444444444444
# 0.9722222222222222

# %%
regions_df=pd.DataFrame.from_dict(data, orient='index')

# %%
regions_df=regions_df.drop_duplicates()

# %%
regions_df.to_csv('regions_df.csv')

# %% [markdown]
# ## wine body

# %%
def get_body(sample):
    return {
        'body_id':get_data(sample, 'vintage.wine.style.body'),
        'description':get_data(sample, 'vintage.wine.style.body_description')}

# %%
get_body(sample)
# Out:
# {'body_id': 4, 'description': 'Corsé'}

# %%
data={}
tot=len(los)
for ix,i in enumerate(los):
    data[ix]=get_body(i)
    if ix%100==0:
        print(ix/tot)
# Out:
# 0.0
# 0.027777777777777776
# 0.05555555555555555
# 0.08333333333333333
# 0.1111111111111111
# 0.1388888888888889
# 0.16666666666666666
# 0.19444444444444445
# 0.2222222222222222
# 0.25
# 0.2777777777777778
# 0.3055555555555556
# 0.3333333333333333
# 0.3611111111111111
# 0.3888888888888889
# 0.4166666666666667
# 0.4444444444444444
# 0.4722222222222222
# 0.5
# 0.5277777777777778
# 0.5555555555555556
# 0.5833333333333334
# 0.6111111111111112
# 0.6388888888888888
# 0.6666666666666666
# 0.6944444444444444
# 0.7222222222222222
# 0.75
# 0.7777777777777778
# 0.8055555555555556
# 0.8333333333333334
# 0.8611111111111112
# 0.8888888888888888
# 0.9166666666666666
# 0.9444444444444444
# 0.9722222222222222

# %%
body_df=pd.DataFrame.from_dict(data, orient='index').drop_duplicates()

# %%
body_df.shape
# Out:
# (5, 2)

# %%
body_df.to_csv('body_df.csv')

# %% [markdown]
# ## acidity

# %%
def get_acidity(sample):
    return {
        'acidity_id':get_data(sample, 'vintage.wine.style.acidity'),
        'description':get_data(sample, 'vintage.wine.style.acidity_description')}
get_acidity(sample)
# Out:
# {'acidity_id': 3, 'description': 'Élevée'}

# %%
data={}
tot=len(los)
for ix,i in enumerate(los):
    data[ix]=get_acidity(i)
    if ix%100==0:
        print(ix/tot)
# Out:
# 0.0
# 0.027777777777777776
# 0.05555555555555555
# 0.08333333333333333
# 0.1111111111111111
# 0.1388888888888889
# 0.16666666666666666
# 0.19444444444444445
# 0.2222222222222222
# 0.25
# 0.2777777777777778
# 0.3055555555555556
# 0.3333333333333333
# 0.3611111111111111
# 0.3888888888888889
# 0.4166666666666667
# 0.4444444444444444
# 0.4722222222222222
# 0.5
# 0.5277777777777778
# 0.5555555555555556
# 0.5833333333333334
# 0.6111111111111112
# 0.6388888888888888
# 0.6666666666666666
# 0.6944444444444444
# 0.7222222222222222
# 0.75
# 0.7777777777777778
# 0.8055555555555556
# 0.8333333333333334
# 0.8611111111111112
# 0.8888888888888888
# 0.9166666666666666
# 0.9444444444444444
# 0.9722222222222222

# %%
acidity_df=pd.DataFrame.from_dict(data, orient='index').drop_duplicates()

# %%
acidity_df.to_csv('acidity_df.csv')

# %% [markdown]
# ## meat_info

# %%
data=[]
tot=len(los)
for ix,js in enumerate(los):
    try:
        data.extend([{j:k for j,k in i.items() if j in ['id','name','seo_name']} for i in get_data(js, 'vintage.wine.foods') if get_data(js, 'vintage.wine.foods')])
    except:
        continue
    if ix%100==0:
        print(ix/tot)
# Out:
# 0.0
# 0.027777777777777776
# 0.05555555555555555
# 0.08333333333333333
# 0.1111111111111111
# 0.1388888888888889
# 0.16666666666666666
# 0.19444444444444445
# 0.2222222222222222
# 0.25
# 0.2777777777777778
# 0.3055555555555556
# 0.3333333333333333
# 0.3611111111111111
# 0.3888888888888889
# 0.4166666666666667
# 0.4444444444444444
# 0.4722222222222222
# 0.5
# 0.5277777777777778
# 0.5555555555555556
# 0.5833333333333334
# 0.6111111111111112
# 0.6388888888888888
# 0.6666666666666666
# 0.6944444444444444
# 0.7222222222222222
# 0.75
# 0.7777777777777778
# 0.8055555555555556
# 0.8333333333333334
# 0.8611111111111112
# 0.8888888888888888
# 0.9166666666666666
# 0.9444444444444444
# 0.9722222222222222

# %%
meat_info_df=pd.DataFrame(data).drop_duplicates().sort_values(by='id').set_index('id')

# %%
meat_info_df.to_csv('meat_info_df.csv')

# %% [markdown]
# ## wine meat

# %%
def get_meat_wine(sample):
    return pd.DataFrame.from_dict({
    'wine_id':get_data(sample, 'vintage.wine.id'),
    'food_id':[i['id'] for i in get_data(sample, 'vintage.wine.foods')]
})

# %%
get_meat_wine(sample)
# Out:
#    wine_id  food_id
# 0    82472        4
# 1    82472        9
# 2    82472       11
# 3    82472       20

# %%
data=pd.DataFrame()
tot=len(los)
for ix,js in enumerate(los):
    try:
        data=data.append(get_meat_wine(js))
    except:
        continue
    if ix%100==0:
        print(ix/tot)
# Out:
# 0.0
# 0.027777777777777776
# 0.05555555555555555
# 0.08333333333333333
# 0.1111111111111111
# 0.1388888888888889
# 0.16666666666666666
# 0.19444444444444445
# 0.2222222222222222
# 0.25
# 0.2777777777777778
# 0.3055555555555556
# 0.3333333333333333
# 0.3611111111111111
# 0.3888888888888889
# 0.4166666666666667
# 0.4444444444444444
# 0.4722222222222222
# 0.5
# 0.5277777777777778
# 0.5555555555555556
# 0.5833333333333334
# 0.6111111111111112
# 0.6388888888888888
# 0.6666666666666666
# 0.6944444444444444
# 0.7222222222222222
# 0.75
# 0.7777777777777778
# 0.8055555555555556
# 0.8333333333333334
# 0.8611111111111112
# 0.8888888888888888
# 0.9166666666666666
# 0.9444444444444444
# 0.9722222222222222

# %%
data=data.drop_duplicates()

# %%
data.to_csv('meat_wine_df.csv')

# %% [markdown]
# ## country

# %%
def get_country(sample):
    return {
    'code':get_data(sample, 'vintage.wine.region.country.code'),
    'name':get_data(sample, 'vintage.wine.region.country.name'),
    'currency':get_data(sample, 'vintage.wine.region.country.currency.code'),
    'regions_count':get_data(sample, 'vintage.wine.region.country.regions_count'),
    'users_count':get_data(sample, 'vintage.wine.region.country.users_count'),
    'wines_count':get_data(sample, 'vintage.wine.region.country.wines_count'),
    'wineries_count':get_data(sample, 'vintage.wine.region.country.wineries_count'),
}

# %%
data={}
tot=len(los)
for ix,i in enumerate(los):
    data[ix]=get_country(i)
    if ix%100==0:
        print(ix/tot)
# Out:
# 0.0
# 0.027777777777777776
# 0.05555555555555555
# 0.08333333333333333
# 0.1111111111111111
# 0.1388888888888889
# 0.16666666666666666
# 0.19444444444444445
# 0.2222222222222222
# 0.25
# 0.2777777777777778
# 0.3055555555555556
# 0.3333333333333333
# 0.3611111111111111
# 0.3888888888888889
# 0.4166666666666667
# 0.4444444444444444
# 0.4722222222222222
# 0.5
# 0.5277777777777778
# 0.5555555555555556
# 0.5833333333333334
# 0.6111111111111112
# 0.6388888888888888
# 0.6666666666666666
# 0.6944444444444444
# 0.7222222222222222
# 0.75
# 0.7777777777777778
# 0.8055555555555556
# 0.8333333333333334
# 0.8611111111111112
# 0.8888888888888888
# 0.9166666666666666
# 0.9444444444444444
# 0.9722222222222222

# %%
countries_df=pd.DataFrame.from_dict(data, orient='index').drop_duplicates()

# %%
countries_df=countries_df.reset_index(drop=True)

# %%
countries_df.to_csv('countries_df.csv')

# %% [markdown]
# ## wine grapes

# %%
def get_grapes_wine(sample):
    return pd.DataFrame.from_dict(pd.DataFrame.from_dict({
    'wine_id':get_data(sample, 'vintage.wine.id'),
    'grape_id':list(get_data(sample, 'vintage.grape_composition').keys()),
    'grapes_share':list(get_data(sample, 'vintage.grape_composition').values())
}))

# %%
data=pd.DataFrame()
tot=len(los)
for ix,js in enumerate(los):
    try:
        data=data.append(get_grapes_wine(js))
    except:
        continue
    if ix%100==0:
        print(ix/tot)

data=data.drop_duplicates()
data
# Out:
# 0.0
# 0.027777777777777776
# 0.05555555555555555
# 0.08333333333333333
# 0.1111111111111111
# 0.1388888888888889
# 0.16666666666666666
# 0.19444444444444445
# 0.2222222222222222
# 0.25
# 0.2777777777777778
# 0.3055555555555556
# 0.3333333333333333
# 0.3611111111111111
# 0.3888888888888889
# 0.4166666666666667
# 0.4444444444444444
# 0.4722222222222222
# 0.5
# 0.5277777777777778
# 0.5555555555555556
# 0.5833333333333334
# 0.6111111111111112
# 0.6388888888888888
# 0.6666666666666666
# 0.6944444444444444
# 0.7222222222222222
# 0.75
# 0.7777777777777778
# 0.8055555555555556
# 0.8333333333333334
# 0.8611111111111112
# 0.8888888888888888
# 0.9166666666666666
# 0.9444444444444444
# 0.9722222222222222
#     wine_id grape_id  grapes_share
# 0   1163903       19         100.0
# 0      1873        9         100.0
# 0      4848       10           0.0
# 1      4848        2         100.0
# 2      4848        3           0.0
# ..      ...      ...           ...
# 0   1252559       10           0.0
# ...

# %%
data.to_csv('wine_grapes_df.csv')

# %% [markdown]
# ## prices

# %%
get_data(sample, 'prices_and_availability.merchants_with_prices')
# Out:
# [{'merchant': {'id': 2768,
#    'name': '20surVin',
#    'seo_name': 'merchant-20survin',
#    'legal_name': None,
#    'description': 'Livraison offerte dès 250 EUR',
#    'country': {'code': 'fr',
#     'name': 'France',
#     'native_name': 'France',
#     'seo_name': 'france',
#     'currency': {'code': 'EUR',
#      'name': 'Euros',
#      'prefix': '€',
#      'suffix': None},
#     'regions_count': 1280,
#     'users_count': 3790550,
#     'wines_count': 481923,
#     'wineries_count': 64952,
#     'most_used_grapes': [{'id': 14,
#       'name': 'Pinot Noir',
#       'seo_name': 'pinot-noir',
#       'has_detailed_info': True,
#       'wines_count': 462117},
#      {'id': 10,
#       'name': 'Merlot',
#       'seo_name': 'merlot',
#       'has_detailed_info': True,
#       'wines_count': 461197},
#      {'id': 5,
#       'name': 'Chardonnay',
#       'seo_name': 'chardonnay',
#       'has_detailed_info': True,
#       'wines_count': 487962}]},
#    'state': None,
# ...

# %%
{k for i in get_data(sample, 'prices_and_availability.merchants_with_prices') for j in i['prices'] for k in j.keys()}
# Out:
# {'amount',
#  'bottle_type',
#  'bottle_type_id',
#  'bottles_sold_count',
#  'currency',
#  'discounted_from',
#  'id',
#  'importer_address',
#  'inventory_bottles_count',
#  'message',
#  'producer_address',
#  'url',
#  'vintage_id'}

# %%
def get_prices_per_merchant(sample):
    data=[]
    for i in get_data(sample, 'prices_and_availability.merchants_with_prices'):
        for j in i['prices']:
            dct={'vintage_id':get_data(j,'vintage_id'),
            'merchant_id':get_data(i,'merchant.id'),
            'price':get_data(j,'amount'),
            'currency':get_data(j,'currency.code'),
            'bottles_in_stock':get_data(j,'inventory_bottles_count'),
            'bottles_sold':get_data(j,'bottles_sold_count'),
            'message':get_data(j,'message'),
            'bottle_volume_ml':get_data(j,'bottle_type.volume_ml')}
            data.append(dct)
    return data

# %%
data=[]
tot=len(los)
for ix,js in enumerate(los):
    data.extend(get_prices_per_merchant(js))
    if ix%200==0:
        print(ix/tot)

data=pd.DataFrame(data).drop_duplicates()
data
# Out:
# 0.0
# 0.05555555555555555
# 0.1111111111111111
# 0.16666666666666666
# 0.2222222222222222
# 0.2777777777777778
# 0.3333333333333333
# 0.3888888888888889
# 0.4444444444444444
# 0.5
# 0.5555555555555556
# 0.6111111111111112
# 0.6666666666666666
# 0.7222222222222222
# 0.7777777777777778
# 0.8333333333333334
# 0.8888888888888888
# 0.9444444444444444
#        vintage_id  merchant_id   price currency  bottles_in_stock  \
# 0        14201617        23215   19.50      EUR               NaN
# 1        14201617         6688   23.33      EUR             612.0
# 2        14201617         2682   16.90      EUR               NaN
# 3        14201617        22706   24.90      EUR               NaN
# 4        14201617         1316   14.90      EUR               NaN
# ...           ...          ...     ...      ...               ...
# 13402     1226840         1346   78.00      EUR               NaN
# 13403     1226840        22897  207.00      EUR               NaN
# ...

# %%
data.to_csv('prices.csv')

# %% [markdown]
# ## appelation

# %%
def get_appelation(sample):
    return {i:j if isinstance(j,(str,int)) else '\n'.join(j) if isinstance(j,list) else j['code'] for i,j in get_data(sample,'vintage.wine.style').items() if i in ['id','regional_name','name','description','interesting_facts','country']}

# %%
data=[]
tot=len(los)
for ix,js in enumerate(los):
    try:
        data.append(get_appelation(js))
    except:
        continue
    if ix%100==0:
        print(ix/tot)

data=pd.DataFrame(data).drop_duplicates()
data
# Out:
# 0.0
# 0.027777777777777776
# 0.05555555555555555
# 0.08333333333333333
# 0.1111111111111111
# 0.1388888888888889
# 0.16666666666666666
# 0.19444444444444445
# 0.2222222222222222
# 0.25
# 0.2777777777777778
# 0.3055555555555556
# 0.3333333333333333
# 0.3611111111111111
# 0.3888888888888889
# 0.4166666666666667
# 0.4444444444444444
# 0.5
# 0.5277777777777778
# 0.5555555555555556
# 0.5833333333333334
# 0.6111111111111112
# 0.6388888888888888
# 0.6666666666666666
# 0.6944444444444444
# 0.7222222222222222
# 0.75
# 0.7777777777777778
# 0.8055555555555556
# 0.8333333333333334
# 0.8611111111111112
# 0.8888888888888888
# 0.9166666666666666
# 0.9444444444444444
# 0.9722222222222222
#        id   regional_name                        name  \
# 0     190         Spanish       Rioja rouge (Espagne)
# 1      98     Argentinian          Malbec (Argentine)
# 2     212  Southern Rhône      Vin rouge du Rhône Sud
# 3      19        Bordeaux       Vin rouge de Bordeaux
# ...

# %%
data.to_csv('appelations.csv')

# %% [markdown]
# ## winery

# %%
def get_winery(sample):
    return {
    'id':get_data(sample, 'vintage.wine.winery.id'),
    'name':get_data(sample, 'vintage.wine.winery.name'),
    'review_status':get_data(sample, 'vintage.wine.winery.review_status'),
    'average_rating':get_data(sample, 'vintage.wine.winery.statistics.ratings_average'),
    'number_of_wines':get_data(sample, 'vintage.wine.winery.statistics.wines_count'),
    'region':get_data(sample, 'vintage.wine.winery.region.id'),
    'business_name':get_data(sample, 'vintage.wine.winery.business_name'),
    'phone':get_data(sample, 'vintage.wine.winery.phone'),
    'email':get_data(sample, 'vintage.wine.winery.email'),
    'winemaker':get_data(sample, 'vintage.wine.winery.winemaker'),
    'website':get_data(sample, 'vintage.wine.winery.website'),
    'latitude':get_data(sample, 'vintage.wine.winery.location.latitude'),
    'longitude':get_data(sample, 'vintage.wine.winery.location.longitude'),

}

# %%
data=[]
tot=len(los)
for ix,js in enumerate(los):
    try:
        data.append(get_winery(js))
    except:
        continue
    if ix%100==0:
        print(ix/tot)

data=pd.DataFrame(data).drop_duplicates()
data
# Out:
# 0.0
# 0.027777777777777776
# 0.05555555555555555
# 0.08333333333333333
# 0.1111111111111111
# 0.1388888888888889
# 0.16666666666666666
# 0.19444444444444445
# 0.2222222222222222
# 0.25
# 0.2777777777777778
# 0.3055555555555556
# 0.3333333333333333
# 0.3611111111111111
# 0.3888888888888889
# 0.4166666666666667
# 0.4444444444444444
# 0.4722222222222222
# 0.5
# 0.5277777777777778
# 0.5555555555555556
# 0.5833333333333334
# 0.6111111111111112
# 0.6388888888888888
# 0.6666666666666666
# 0.6944444444444444
# 0.7222222222222222
# 0.75
# 0.7777777777777778
# 0.8055555555555556
# 0.8333333333333334
# 0.8611111111111112
# 0.8888888888888888
# 0.9166666666666666
# 0.9444444444444444
# 0.9722222222222222
#           id                      name review_status  average_rating  \
# 0       1837         Marqués de Riscal     Completed             3.9
# 1     243362                    Catena     Completed             3.9
# 2       1368                  Opus One     Completed             4.6
# ...

# %%
data.to_csv('wineries.csv')

# %% [markdown]
# ## merchants

# %%
def get_merchants(sample):
    data=[]
    for i in get_data(sample,'prices_and_availability.merchants_with_prices'):
        payments=[]
        bla=get_data(i,'merchant.payment_options.methods')
        if bla:
            bla=[get_data(j,'capabilities') for j in bla]
            if bla:
                payments.extend([get_data(k,'id') for k in bla[0]])
        dct={'id':get_data(i,'merchant.id'),
        'name':get_data(i,'merchant.name'),
        'url':get_data(i,'merchant.tos_url'),
        'payments':payments}
        data.append(dct)
    return data

# %%
data=[]
tot=len(los)
for ix,js in enumerate(los):
    data.extend(get_merchants(js))
    if ix%200==0:
        print(ix/tot)
# Out:
# 0.0
# 0.05555555555555555
# 0.1111111111111111
# 0.16666666666666666
# 0.2222222222222222
# 0.2777777777777778
# 0.3333333333333333
# 0.3888888888888889
# 0.4444444444444444
# 0.5
# 0.5555555555555556
# 0.6111111111111112
# 0.6666666666666666
# 0.7222222222222222
# 0.7777777777777778
# 0.8333333333333334
# 0.8888888888888888
# 0.9444444444444444
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-193-b7b27af078a4> in <module>
#       6         print(ix/tot)
#       7
# ----> 8 data=pd.DataFrame(data).drop_duplicates()
#       9 data
#
# ~/yes/lib/python3.7/site-packages/pandas/core/frame.py in drop_duplicates(self, subset, keep, inplace, ignore_index)
#    4809
#    4810         inplace = validate_bool_kwarg(inplace, "inplace")
# -> 4811         duplicated = self.duplicated(subset, keep=keep)
#    4812
#    4813         if inplace:
#
# ...

# %%
merchants_df=pd.DataFrame(data).drop_duplicates(subset=['id','name','url']).reset_index(drop=True)

# %%
merchants_df.to_csv('merchants_df.csv')

# %% [markdown]
# ## grapes

# %%
def get_grapes(sample):
    return {j:k for i in get_data(sample,'vintage.wine.grapes') for j,k in i.items() if j in ['id','name','wines_count']}

# %%
data=[]
tot=len(los)
for ix,js in enumerate(los):
    try:
        data.append(get_grapes(js))
    except:
        continue
    if ix%100==0:
        print(ix/tot)

data=pd.DataFrame(data).drop_duplicates()
data
# Out:
# 0.0
# 0.027777777777777776
# 0.05555555555555555
# 0.08333333333333333
# 0.1111111111111111
# 0.1388888888888889
# 0.16666666666666666
# 0.19444444444444445
# 0.2222222222222222
# 0.25
# 0.2777777777777778
# 0.3055555555555556
# 0.3333333333333333
# 0.3611111111111111
# 0.3888888888888889
# 0.4166666666666667
# 0.4444444444444444
# 0.4722222222222222
# 0.5
# 0.5277777777777778
# 0.5555555555555556
# 0.5833333333333334
# 0.6111111111111112
# 0.6388888888888888
# 0.6666666666666666
# 0.6944444444444444
# 0.7222222222222222
# 0.75
# 0.7777777777777778
# 0.8055555555555556
# 0.8333333333333334
# 0.8611111111111112
# 0.8888888888888888
# 0.9166666666666666
# 0.9444444444444444
# 0.9722222222222222
#         id                   name  wines_count
# 0       81               Graciano        10215
# 1        9                 Malbec       179553
# 2       10                 Merlot       461197
# 3       22              Mourvedre        80271
# 5       16             Sangiovese       103884
# ...

# %%
data.to_csv('grapes_df.csv')

# %% [markdown]
# ## wine critics

# %%
sample=get_new_link()
get_data(sample,'vintage.wine_critic_reviews')
# Out:
# https://www.vivino.com/chateau-la-louviere-pessac-leognan/w/1557446?year=2014&price_id=9906522
# [{'id': 1371329,
#   'wine_critic_id': 35,
#   'score': '86',
#   'score_normalized': 86,
#   'reviewed_at': '2017-02-06T00:00:00Z'},
#  {'id': 1868721,
#   'wine_critic_id': 1,
#   'score': '92',
#   'score_normalized': 92,
#   'reviewed_at': '2017-03-31T00:00:00Z'},
#  {'id': 2546239,
#   'wine_critic_id': 12,
#   'score': '88',
#   'score_normalized': 88,
#   'reviewed_at': '2015-04-01T00:00:00Z'},
#  {'id': 2567702,
#   'wine_critic_id': 12,
#   'score': '87',
#   'score_normalized': 87,
#   'reviewed_at': '2015-04-01T00:00:00Z'}]

# %%
def get_critics(sample):
    vin_id=get_data(sample, 'vintage.id')

    data=[]
    for i in get_data(sample,'vintage.wine_critic_reviews'):
        dct={}
        for j,k in i.items():
            if j in ['id','score_normalized','reviewed_at']:
                dct[j]=k
        dct['vintage_id']=vin_id
        data.append(dct)
    return data

# %%
data=[]
tot=len(los)
for ix,js in enumerate(los):
    try:
        data.extend(get_critics(js))
    except:
        continue
    if ix%100==0:
        print(ix/tot)

data=pd.DataFrame(data).drop_duplicates()
data
# Out:
# 0.0
# 0.027777777777777776
# 0.05555555555555555
# 0.08333333333333333
# 0.1111111111111111
# 0.1388888888888889
# 0.16666666666666666
# 0.19444444444444445
# 0.2222222222222222
# 0.25
# 0.2777777777777778
# 0.3055555555555556
# 0.3333333333333333
# 0.3611111111111111
# 0.3888888888888889
# 0.4166666666666667
# 0.4444444444444444
# 0.4722222222222222
# 0.5
# 0.5277777777777778
# 0.5555555555555556
# 0.5833333333333334
# 0.6111111111111112
# 0.6388888888888888
# 0.6666666666666666
# 0.6944444444444444
# 0.7222222222222222
# 0.75
# 0.7777777777777778
# 0.8055555555555556
# 0.8333333333333334
# 0.8611111111111112
# 0.8888888888888888
# 0.9166666666666666
# 0.9444444444444444
# 0.9722222222222222
#            id  score_normalized           reviewed_at  vintage_id
# 0     3505777               100  2020-03-27T00:00:00Z    14201617
# 1     3505778                93  2015-01-01T00:00:00Z    14201617
# 2     3005399                90  2018-06-01T00:00:00Z   150296971
# ...

# %%
data.to_csv('critics_df.csv')
